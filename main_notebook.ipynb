# %% [markdown]
# ### Download SpeechBrain-MOABB benchmarks

# %%
# %%capture
# !git clone https://github.com/speechbrain/benchmarks
# %cd benchmarks
# !git checkout eeg

# %cd benchmarks/benchmarks/MOABB
# %pip install -r extra-requirements.txt # Install additional dependencies

# %cd ..

# %% [markdown]
# ### Install the requirements

# %%
# %%capture
# Clone SpeechBrain repository (development branch)
# !git clone https://github.com/speechbrain/speechbrain/
# %cd speechbrain/

# Install required dependencies
# %pip install -r requirements.txt

# Install SpeechBrain in editable mode
# %pip install -e .

# %cd ..

# %%
# %pip install -q mne moabb orion scikit-learn torch torchinfo

import mne
import moabb
import orion
import sklearn
import torch
import torchinfo
# Out:
# Note: you may need to restart the kernel to use updated packages.
# <frozen importlib._bootstrap>:241: FutureWarning: mne.io.pick.pick_types is deprecated will be removed in 1.6, use documented public API instead. If no appropriate public API exists, please open an issue on GitHub.
# <frozen importlib._bootstrap>:241: FutureWarning: mne.io.pick.pick_channels_regexp is deprecated will be removed in 1.6, use documented public API instead. If no appropriate public API exists, please open an issue on GitHub.
# <frozen importlib._bootstrap>:241: FutureWarning: mne.io.pick.channel_type is deprecated will be removed in 1.6, use documented public API instead. If no appropriate public API exists, please open an issue on GitHub.
# /Users/quan/.pyenv/versions/3.10.12/lib/python3.10/site-packages/moabb/pipelines/__init__.py:26: ModuleNotFoundError: Tensorflow is not installed. You won't be able to use these MOABB pipelines if you attempt to do so.
#   warn(
# To use the get_shape_from_baseconcar, InputShapeSetterEEG, BraindecodeDatasetLoaderyou need to install `braindecode`.`pip install braindecode` or Please refer to `https://braindecode.org`.

# %%
# %pip install hyperpyyaml
from hyperpyyaml import load_hyperpyyaml, dump_hyperpyyaml

example_hyperparams = """
seed: 1234
__set_torchseed: !apply:torch.manual_seed [!ref <seed>]

# DIRECTORIES
data_folder: !PLACEHOLDER  #'/path/to/dataset'. The dataset will be automatically downloaded in this folder
cached_data_folder: !PLACEHOLDER #'path/to/pickled/dataset'
output_folder: !PLACEHOLDER #'path/to/results'

# DATASET HPARS
# Defining the MOABB dataset.
dataset: !new:moabb.datasets.BNCI2014001
save_prepared_dataset: True # set to True if you want to save the prepared dataset as a pkl file to load and use afterwards
data_iterator_name: 'leave-one-session-out'
target_subject_idx: 0
target_session_idx: 1
events_to_load: null # all events will be loaded
original_sample_rate: 250 # Original sampling rate provided by dataset authors
sample_rate: 125 # Target sampling rate (Hz)
# band-pass filtering cut-off frequencies
fmin: 1
fmax: 40
n_classes: 4
tmin: 0.
tmax: 4.0
# number of steps used when selecting adjacent channels from a seed channel (default at Cz)
n_steps_channel_selection: 3
T: !apply:math.ceil
    - !ref <sample_rate> * (<tmax> - <tmin>)
C: 22
test_with: 'best' # 'last' or 'best'
test_key: "acc" # Possible opts: "loss", "f1", "auc", "acc"

# METRICS
f1: !name:sklearn.metrics.f1_score
    average: 'macro'
acc: !name:sklearn.metrics.balanced_accuracy_score
cm: !name:sklearn.metrics.confusion_matrix
metrics:
    f1: !ref <f1>
    acc: !ref <acc>
    cm: !ref <cm>

# TRAINING HPARS
n_train_examples: 100  # it will be replaced in the train script
# checkpoints to average
avg_models: 10
number_of_epochs: 1000
lr: 0.0001
# Learning rate scheduling (cyclic learning rate is used here)
max_lr: !ref <lr> # Upper bound of the cycle (max value of the lr)
base_lr: 0.00000001 # Lower bound in the cycle (min value of the lr)
step_size_multiplier: 5 #from 2 to 8
step_size: !apply:round
    - !ref <step_size_multiplier> * <n_train_examples> / <batch_size>
lr_annealing: !new:speechbrain.nnet.schedulers.CyclicLRScheduler
    base_lr: !ref <base_lr>
    max_lr: !ref <max_lr>
    step_size: !ref <step_size>
label_smoothing: 0.0
loss: !name:speechbrain.nnet.losses.nll_loss
    label_smoothing: !ref <label_smoothing>
optimizer: !name:torch.optim.Adam
    lr: !ref <lr>
epoch_counter: !new:speechbrain.utils.epoch_loop.EpochCounter  # epoch counter
    limit: !ref <number_of_epochs>
batch_size: 32
valid_ratio: 0.2

# DATA NORMALIZATION
dims_to_normalize: 1 # 1 (time) or 2 (EEG channels)
normalize: !name:speechbrain.processing.signal_processing.mean_std_norm
    dims: !ref <dims_to_normalize>

# MODEL
input_shape: [null, !ref <T>, !ref <C>, null]
cnn_temporal_kernels: 8
cnn_temporal_kernelsize: 62
cnn_spatial_depth_multiplier: 2
cnn_spatial_max_norm: 1.
cnn_spatial_pool: 4
cnn_septemporal_depth_multiplier: 1
cnn_septemporal_point_kernels: !ref <cnn_temporal_kernels> * <cnn_spatial_depth_multiplier> * <cnn_septemporal_depth_multiplier>
cnn_septemporal_kernelsize: 16
cnn_septemporal_pool: 8
cnn_pool_type: 'avg'
dense_max_norm: 0.25
dropout: 0.5
activation_type: 'elu'

model: !new:models.EEGNet.EEGNet
    input_shape: !ref <input_shape>
    cnn_temporal_kernels: !ref <cnn_temporal_kernels>
    cnn_temporal_kernelsize: [!ref <cnn_temporal_kernelsize>, 1]
    cnn_spatial_depth_multiplier: !ref <cnn_spatial_depth_multiplier>
    cnn_spatial_max_norm: !ref <cnn_spatial_max_norm>
    cnn_spatial_pool: [!ref <cnn_spatial_pool>, 1]
    cnn_septemporal_depth_multiplier: !ref <cnn_septemporal_depth_multiplier>
    cnn_septemporal_point_kernels: !ref <cnn_septemporal_point_kernels>
    cnn_septemporal_kernelsize: [!ref <cnn_septemporal_kernelsize>, 1]
    cnn_septemporal_pool: [!ref <cnn_septemporal_pool>, 1]
    cnn_pool_type: !ref <cnn_pool_type>
    activation_type: !ref <activation_type>
    dense_max_norm: !ref <dense_max_norm>
    dropout: !ref <dropout>
    dense_n_neurons: !ref <n_classes>

"""
# Out:
# Requirement already satisfied: hyperpyyaml in /Users/quan/.pyenv/versions/3.10.12/lib/python3.10/site-packages (1.2.2)
# Requirement already satisfied: pyyaml>=5.1 in /Users/quan/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from hyperpyyaml) (6.0.1)
# Requirement already satisfied: ruamel.yaml>=0.17.28 in /Users/quan/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from hyperpyyaml) (0.18.6)
# Requirement already satisfied: ruamel.yaml.clib>=0.2.7 in /Users/quan/.pyenv/versions/3.10.12/lib/python3.10/site-packages (from ruamel.yaml>=0.17.28->hyperpyyaml) (0.2.8)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Save the yaml file on disk
f = open('example_hyperparams.yaml', "w")
f.write(example_hyperparams)
f.close()

# %%
data_augmentation_hyperparams = """
# DATA AUGMENTATION
# cutcat (disabled when min_num_segments=max_num_segments=1)
max_num_segments: 3 # @orion_step2: --max_num_segments~"uniform(2, 6, discrete=True)"
cutcat: !new:speechbrain.augment.time_domain.CutCat
    min_num_segments: 2
    max_num_segments: !ref <max_num_segments>
# random amplitude gain between 0.5-1.5 uV (disabled when amp_delta=0.)
amp_delta: 0.01742 # @orion_step2: --amp_delta~"uniform(0.0, 0.5)"
rand_amp: !new:speechbrain.augment.time_domain.RandAmp
    amp_low: !ref 1 - <amp_delta>
    amp_high: !ref 1 + <amp_delta>
# random shifts between -300 ms to 300 ms (disabled when shift_delta=0.)
shift_delta_: 1 # orion_step2: --shift_delta_~"uniform(0, 25, discrete=True)"
shift_delta: !ref 1e-2 * <shift_delta_> # 0.250 # 0.-0.25 with steps of 0.01
min_shift: !apply:math.floor
    - !ref 0 - <sample_rate> * <shift_delta>
max_shift: !apply:math.floor
    - !ref 0 + <sample_rate> * <shift_delta>
time_shift: !new:speechbrain.augment.freq_domain.RandomShift
    min_shift: !ref <min_shift>
    max_shift: !ref <max_shift>
    dim: 1
# injection of gaussian white noise
snr_white_low: 15.0 # @orion_step2: --snr_white_low~"uniform(0.0, 15, precision=2)"
snr_white_delta: 19.1 # @orion_step2: --snr_white_delta~"uniform(5.0, 20.0, precision=3)"
snr_white_high: !ref <snr_white_low> + <snr_white_delta>
add_noise_white: !new:speechbrain.augment.time_domain.AddNoise
    snr_low: !ref <snr_white_low>
    snr_high: !ref <snr_white_high>

repeat_augment: 1 # @orion_step1: --repeat_augment 0
augment: !new:speechbrain.augment.augmenter.Augmenter
    parallel_augment: True
    concat_original: True
    parallel_augment_fixed_bs: True
    repeat_augment: !ref <repeat_augment>
    shuffle_augmentations: True
    min_augmentations: 4
    max_augmentations: 4
    augmentations: [
        # !ref <cutcat>,
        # !ref <rand_amp>,
        # !ref <time_shift>,
        # !ref <add_noise_white>]
"""

example_hyperparams += data_augmentation_hyperparams

# %% [markdown]
# ### Train the neural network on a single cross-validation fold

# %%
# %cd ./benchmarks/benchmarks/MOABB/

# !python train.py ../../../example_hyperparams.yaml\
--data_folder 'data/BNCI2014001' \
--cached_data_folder 'data/' \
--output_folder 'results/single-fold-example/BNCI2014001' \
--data_iterator_name 'leave-one-session-out' \
--target_subject_idx 0 \
--target_session_idx 1 \
--number_of_epochs 50 \
--device 'cpu' # Switch to cuda for a speed up.
# Out:
# [Errno 2] No such file or directory: './benchmarks/benchmarks/MOABB/'
# /Users/quan/Documents/Concordia Classes/COMP432/speechbrain_moabb_project/benchmarks/benchmarks/MOABB
# /Users/quan/.pyenv/versions/3.10.12/lib/python3.10/site-packages/IPython/core/magics/osm.py:393: UserWarning: This is now an optional IPython functionality, using bookmarks requires you to install the `pickleshare` library.
#   bkms = self.shell.db.get('bookmarks', {})
# <frozen importlib._bootstrap>:241: FutureWarning: mne.io.pick.pick_types is deprecated will be removed in 1.6, use documented public API instead. If no appropriate public API exists, please open an issue on GitHub.
# <frozen importlib._bootstrap>:241: FutureWarning: mne.io.pick.pick_channels_regexp is deprecated will be removed in 1.6, use documented public API instead. If no appropriate public API exists, please open an issue on GitHub.
# <frozen importlib._bootstrap>:241: FutureWarning: mne.io.pick.channel_type is deprecated will be removed in 1.6, use documented public API instead. If no appropriate public API exists, please open an issue on GitHub.
# /Users/quan/.pyenv/versions/3.10.12/lib/python3.10/site-packages/moabb/pipelines/__init__.py:26: ModuleNotFoundError: Tensorflow is not installed. You won't be able to use these MOABB pipelines if you attempt to do so.
#   warn(
# To use the get_shape_from_baseconcar, InputShapeSetterEEG, BraindecodeDatasetLoaderyou need to install `braindecode`.`pip install braindecode` or Please refer to `https://braindecode.org`.
# torchvision is not available - cannot save figures
# SpeechBrain could not find any working torchaudio backend. Audio files may fail to load. Follow this link for instructions and troubleshooting: https://pytorch.org/audio/stable/index.html
# SpeechBrain could not find any working torchaudio backend. Audio files may fail to load. Follow this link for instructions and troubleshooting: https://pytorch.org/audio/stable/index.html
# BNCI2014001 has been renamed to BNCI2014_001. BNCI2014001 will be removed in version 1.1.
# The dataset class name 'BNCI2014001' must be an abbreviation of its code 'BNCI2014-001'. See moabb.datasets.base.is_abbrev for more information.
# Prepare dataset iterators...
# data/BNCI2014001
# Choosing from all possible events
# MNE_DATA is not already configured. It will be set to default location in the home directory - /Users/quan/mne_data
# All datasets will be downloaded to this location, if anything is already downloaded, please move manually to this location
# /Users/quan/.pyenv/versions/3.10.12/lib/python3.10/site-packages/moabb/datasets/download.py:55: RuntimeWarning: Setting non-standard config type: "MNE_DATASETS_BNCI_PATH"
#   set_config(key, get_config("MNE_DATA"))
# Downloading data from 'http://bnci-horizon-2020.eu/database/data-sets/001-2014/A01T.mat' to file '/Users/quan/mne_data/MNE-bnci-data/database/data-sets/001-2014/A01T.mat'.
# /Users/quan/.pyenv/versions/3.10.12/lib/python3.10/site-packages/urllib3/connectionpool.py:1061: InsecureRequestWarning: Unverified HTTPS request is being made to host 'lampx.tugraz.at'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# 100%|██████████████████████████████████████| 42.8M/42.8M [00:00<00:00, 268GB/s]
# SHA256 hash of downloaded file: 054f02e70cf9c4ada1517e9b9864f45407939c1062c6793516585c6f511d0325
# Use this value as the 'known_hash' argument of 'pooch.retrieve' to ensure that the file hasn't changed if it is downloaded again in the future.
# Downloading data from 'http://bnci-horizon-2020.eu/database/data-sets/001-2014/A01E.mat' to file '/Users/quan/mne_data/MNE-bnci-data/database/data-sets/001-2014/A01E.mat'.
# /Users/quan/.pyenv/versions/3.10.12/lib/python3.10/site-packages/urllib3/connectionpool.py:1061: InsecureRequestWarning: Unverified HTTPS request is being made to host 'lampx.tugraz.at'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# 100%|██████████████████████████████████████| 43.8M/43.8M [00:00<00:00, 296GB/s]
# SHA256 hash of downloaded file: 53d415f39c3d7b0c88b894d7b08d99bcdfe855ede63831d3691af1a45607fb62
# Use this value as the 'known_hash' argument of 'pooch.retrieve' to ensure that the file hasn't changed if it is downloaded again in the future.
# Saving the dataset at data/MOABB_pickled/BNCI2014-001/0125_001-040/sub-001.pkl
# Session/sessions used as training and validation set: ['0train']
# Session used as test set: ['1test']
# Validation indices: [3, 16, 38, 58, 79, 110, 130, 152, 176, 197, 223, 240, 270, 287, 2, 20, 42, 72, 90, 112, 129, 156, 170, 201, 210, 242, 257, 286, 1, 33, 43, 62, 80, 111, 137, 150, 177, 199, 230, 245, 262, 284, 0, 25, 39, 66, 86, 107, 119, 157, 173, 196, 214, 241, 250, 276]
# Sampling all channels available: ['Fz', 'FC3', 'FC1', 'FCz', 'FC2', 'FC4', 'C5', 'C3', 'C1', 'Cz', 'C2', 'C4', 'C6', 'CP3', 'CP1', 'CPz', 'CP2', 'CP4', 'P1', 'Pz', 'P2', 'POz']
# Sampling all channels available: ['Fz', 'FC3', 'FC1', 'FCz', 'FC2', 'FC4', 'C5', 'C3', 'C1', 'Cz', 'C2', 'C4', 'C6', 'CP3', 'CP1', 'CPz', 'CP2', 'CP4', 'P1', 'Pz', 'P2', 'POz']
# Sampling all channels available: ['Fz', 'FC3', 'FC1', 'FCz', 'FC2', 'FC4', 'C5', 'C3', 'C1', 'Cz', 'C2', 'C4', 'C6', 'CP3', 'CP1', 'CPz', 'CP2', 'CP4', 'P1', 'Pz', 'P2', 'POz']
# BNCI2014001 has been renamed to BNCI2014_001. BNCI2014001 will be removed in version 1.1.
# The dataset class name 'BNCI2014001' must be an abbreviation of its code 'BNCI2014-001'. See moabb.datasets.base.is_abbrev for more information.
# speechbrain.core - Beginning experiment!
# speechbrain.core - Experiment folder: results/single-fold-example/BNCI2014001/leave-one-session-out/sub-001/1test
# __main__ - Experiment directory: results/single-fold-example/BNCI2014001/leave-one-session-out/sub-001/1test
# __main__ - Input shape: torch.Size([500, 22, 1])
# __main__ - Training set avg value: 2.2072093486258382e-08
# __main__ - Number of examples: 232 (training), 56 (validation), 288 (test)
# speechbrain.core - Gradscaler enabled: False. Using precision: fp32.
# speechbrain.core - MOABBBrain Model Statistics:
# * Total Number of Trainable Parameters: 2.4k
# * Total Number of Parameters: 2.4k
# * Trainable Parameters represent 100.0000% of the total size.
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# EEGNet                                   [1, 4]                    --
# ├─Sequential: 1-1                        [1, 15, 1, 16]            --
# │    └─Conv2d: 2-1                       [1, 499, 22, 8]           --
# │    │    └─Conv2d: 3-1                  [1, 8, 499, 22]           496
# │    └─BatchNorm2d: 2-2                  [1, 499, 22, 8]           --
# │    │    └─BatchNorm2d: 3-2             [1, 8, 22, 499]           16
# │    └─Conv2d: 2-3                       [1, 499, 1, 16]           --
# │    │    └─Conv2d: 3-3                  [1, 16, 499, 1]           352
# │    └─BatchNorm2d: 2-4                  [1, 499, 1, 16]           --
# │    │    └─BatchNorm2d: 3-4             [1, 16, 1, 499]           32
# │    └─ELU: 2-5                          [1, 499, 1, 16]           --
# │    └─Pooling2d: 2-6                    [1, 124, 1, 16]           --
# │    │    └─AvgPool2d: 3-5               [1, 16, 124, 1]           --
# │    └─Dropout: 2-7                      [1, 124, 1, 16]           --
# │    └─Conv2d: 2-8                       [1, 123, 1, 16]           --
# │    │    └─Conv2d: 3-6                  [1, 16, 123, 1]           256
# │    └─Conv2d: 2-9                       [1, 123, 1, 16]           --
# │    │    └─Conv2d: 3-7                  [1, 16, 123, 1]           256
# │    └─BatchNorm2d: 2-10                 [1, 123, 1, 16]           --
# │    │    └─BatchNorm2d: 3-8             [1, 16, 1, 123]           32
# │    └─ELU: 2-11                         [1, 123, 1, 16]           --
# │    └─Pooling2d: 2-12                   [1, 15, 1, 16]            --
# │    │    └─AvgPool2d: 3-9               [1, 16, 15, 1]            --
# │    └─Dropout: 2-13                     [1, 15, 1, 16]            --
# ├─Sequential: 1-2                        [1, 4]                    --
# │    └─Flatten: 2-14                     [1, 240]                  --
# │    └─Linear: 2-15                      [1, 4]                    --
# │    │    └─Linear: 3-10                 [1, 4]                    964
# │    └─LogSoftmax: 2-16                  [1, 4]                    --
# ==========================================================================================
# Total params: 2,404
# Trainable params: 2,404
# Non-trainable params: 0
# Total mult-adds (M): 5.68
# ==========================================================================================
# Input size (MB): 0.04
# Forward/backward pass size (MB): 1.58
# Params size (MB): 0.01
# Estimated Total Size (MB): 1.63
# ==========================================================================================
# speechbrain.utils.epoch_loop - Going into epoch 1
# speechbrain.nnet.schedulers - Changing lr from 2.2e-05 to 2.5e-05
# speechbrain.utils.train_logger - epoch: 1, lr: 1.95e-05 - train loss: 1.40 - valid loss: 1.39, valid f1: 2.11e-01, valid acc: 2.32e-01, valid cm: [[ 2  0  6  6]
#  [ 5  1  3  5]
#  [ 0  0  4 10]
#  [ 0  0  8  6]]
# speechbrain.utils.epoch_loop - Going into epoch 2
# speechbrain.nnet.schedulers - Changing lr from 4.4e-05 to 4.7e-05
# speechbrain.utils.train_logger - epoch: 2, lr: 4.17e-05 - train loss: 1.40 - valid loss: 1.39, valid f1: 1.67e-01, valid acc: 2.14e-01, valid cm: [[ 2  0  5  7]
#  [ 5  0  4  5]
#  [ 0  0  2 12]
#  [ 0  0  6  8]]
# speechbrain.utils.epoch_loop - Going into epoch 3
# speechbrain.nnet.schedulers - Changing lr from 6.7e-05 to 6.9e-05
# speechbrain.utils.train_logger - epoch: 3, lr: 6.39e-05 - train loss: 1.40 - valid loss: 1.38, valid f1: 1.74e-01, valid acc: 2.50e-01, valid cm: [[ 2  0  3  9]
#  [ 2  0  2 10]
#  [ 0  0  1 13]
#  [ 0  0  3 11]]
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/single-fold-example/BNCI2014001/leave-one-session-out/sub-001/1test/save/CKPT+2024-03-25+00-34-17+00
# speechbrain.utils.epoch_loop - Going into epoch 4
# speechbrain.nnet.schedulers - Changing lr from 8.9e-05 to 9.2e-05
# speechbrain.utils.train_logger - epoch: 4, lr: 8.61e-05 - train loss: 1.39 - valid loss: 1.38, valid f1: 1.73e-01, valid acc: 2.50e-01, valid cm: [[ 2  0  2 10]
#  [ 2  0  2 10]
#  [ 0  0  1 13]
#  [ 0  0  3 11]]
# speechbrain.utils.epoch_loop - Going into epoch 5
# speechbrain.nnet.schedulers - Changing lr from 8.9e-05 to 8.6e-05
# speechbrain.utils.train_logger - epoch: 5, lr: 9.17e-05 - train loss: 1.40 - valid loss: 1.38, valid f1: 1.73e-01, valid acc: 2.50e-01, valid cm: [[ 2  0  2 10]
#  [ 2  0  2 10]
#  [ 0  0  1 13]
#  [ 0  0  3 11]]
# speechbrain.utils.epoch_loop - Going into epoch 6
# speechbrain.nnet.schedulers - Changing lr from 6.7e-05 to 6.4e-05
# speechbrain.utils.train_logger - epoch: 6, lr: 6.94e-05 - train loss: 1.38 - valid loss: 1.38, valid f1: 1.44e-01, valid acc: 2.32e-01, valid cm: [[ 2  0  2 10]
#  [ 3  0  0 11]
#  [ 0  0  0 14]
#  [ 0  0  3 11]]
# speechbrain.utils.epoch_loop - Going into epoch 7
# speechbrain.nnet.schedulers - Changing lr from 4.4e-05 to 4.2e-05
# speechbrain.utils.train_logger - epoch: 7, lr: 4.72e-05 - train loss: 1.38 - valid loss: 1.38, valid f1: 1.67e-01, valid acc: 2.50e-01, valid cm: [[ 3  0  1 10]
#  [ 3  0  0 11]
#  [ 0  0  0 14]
#  [ 0  0  3 11]]
# speechbrain.utils.epoch_loop - Going into epoch 8
# speechbrain.nnet.schedulers - Changing lr from 2.2e-05 to 1.9e-05
# speechbrain.utils.train_logger - epoch: 8, lr: 2.50e-05 - train loss: 1.39 - valid loss: 1.38, valid f1: 1.73e-01, valid acc: 2.68e-01, valid cm: [[ 3  0  1 10]
#  [ 3  0  0 11]
#  [ 0  0  0 14]
#  [ 0  0  2 12]]
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/single-fold-example/BNCI2014001/leave-one-session-out/sub-001/1test/save/CKPT+2024-03-25+00-34-24+00
# speechbrain.utils.epoch_loop - Going into epoch 9
# speechbrain.nnet.schedulers - Changing lr from 1e-08 to 2.8e-06
# speechbrain.utils.train_logger - epoch: 9, lr: 2.79e-06 - train loss: 1.38 - valid loss: 1.38, valid f1: 1.26e-01, valid acc: 2.32e-01, valid cm: [[ 1  0  3 10]
#  [ 3  0  0 11]
#  [ 0  0  0 14]
#  [ 0  0  2 12]]
# speechbrain.utils.epoch_loop - Going into epoch 10
# speechbrain.nnet.schedulers - Changing lr from 2.2e-05 to 2.5e-05
# speechbrain.utils.train_logger - epoch: 10, lr: 1.95e-05 - train loss: 1.38 - valid loss: 1.38, valid f1: 1.25e-01, valid acc: 2.32e-01, valid cm: [[ 1  0  2 11]
#  [ 2  0  0 12]
#  [ 0  0  0 14]
#  [ 0  0  2 12]]
# speechbrain.utils.epoch_loop - Going into epoch 11
# speechbrain.nnet.schedulers - Changing lr from 4.4e-05 to 4.7e-05
# speechbrain.utils.train_logger - epoch: 11, lr: 4.17e-05 - train loss: 1.38 - valid loss: 1.38, valid f1: 1.25e-01, valid acc: 2.32e-01, valid cm: [[ 1  0  2 11]
#  [ 2  0  0 12]
#  [ 0  0  0 14]
#  [ 0  0  2 12]]
# speechbrain.utils.epoch_loop - Going into epoch 12
# speechbrain.nnet.schedulers - Changing lr from 6.7e-05 to 6.9e-05
# speechbrain.utils.train_logger - epoch: 12, lr: 6.39e-05 - train loss: 1.38 - valid loss: 1.38, valid f1: 1.51e-01, valid acc: 2.50e-01, valid cm: [[ 2  0  1 11]
#  [ 2  0  0 12]
#  [ 0  0  0 14]
#  [ 0  0  2 12]]
# speechbrain.utils.epoch_loop - Going into epoch 13
# speechbrain.nnet.schedulers - Changing lr from 8.9e-05 to 9.2e-05
# speechbrain.utils.train_logger - epoch: 13, lr: 8.61e-05 - train loss: 1.38 - valid loss: 1.38, valid f1: 1.49e-01, valid acc: 2.50e-01, valid cm: [[ 2  0  1 11]
#  [ 3  0  0 11]
#  [ 0  0  0 14]
#  [ 0  0  2 12]]
# speechbrain.utils.epoch_loop - Going into epoch 14
# speechbrain.nnet.schedulers - Changing lr from 8.9e-05 to 8.6e-05
# speechbrain.utils.train_logger - epoch: 14, lr: 9.17e-05 - train loss: 1.38 - valid loss: 1.38, valid f1: 1.49e-01, valid acc: 2.50e-01, valid cm: [[ 2  0  1 11]
#  [ 3  0  0 11]
#  [ 0  0  0 14]
#  [ 0  0  2 12]]
# speechbrain.utils.epoch_loop - Going into epoch 15
# speechbrain.nnet.schedulers - Changing lr from 6.7e-05 to 6.4e-05
# speechbrain.utils.train_logger - epoch: 15, lr: 6.94e-05 - train loss: 1.37 - valid loss: 1.38, valid f1: 1.49e-01, valid acc: 2.50e-01, valid cm: [[ 2  0  1 11]
#  [ 3  0  0 11]
#  [ 0  0  0 14]
#  [ 0  0  2 12]]
# speechbrain.utils.epoch_loop - Going into epoch 16
# speechbrain.nnet.schedulers - Changing lr from 4.4e-05 to 4.2e-05
# speechbrain.utils.train_logger - epoch: 16, lr: 4.72e-05 - train loss: 1.37 - valid loss: 1.38, valid f1: 1.51e-01, valid acc: 2.50e-01, valid cm: [[ 2  0  2 10]
#  [ 3  0  0 11]
#  [ 0  0  0 14]
#  [ 0  1  1 12]]
# speechbrain.utils.epoch_loop - Going into epoch 17
# speechbrain.nnet.schedulers - Changing lr from 2.2e-05 to 1.9e-05
# speechbrain.utils.train_logger - epoch: 17, lr: 2.50e-05 - train loss: 1.39 - valid loss: 1.38, valid f1: 1.50e-01, valid acc: 2.50e-01, valid cm: [[ 2  0  2 10]
#  [ 4  0  0 10]
#  [ 0  0  0 14]
#  [ 0  1  1 12]]
# speechbrain.utils.epoch_loop - Going into epoch 18
# speechbrain.nnet.schedulers - Changing lr from 1e-08 to 2.8e-06
# speechbrain.utils.train_logger - epoch: 18, lr: 2.79e-06 - train loss: 1.38 - valid loss: 1.38, valid f1: 1.50e-01, valid acc: 2.50e-01, valid cm: [[ 2  0  2 10]
#  [ 4  0  0 10]
#  [ 0  0  0 14]
#  [ 0  1  1 12]]
# speechbrain.utils.epoch_loop - Going into epoch 19
# speechbrain.nnet.schedulers - Changing lr from 2.2e-05 to 2.5e-05
# speechbrain.utils.train_logger - epoch: 19, lr: 1.95e-05 - train loss: 1.38 - valid loss: 1.38, valid f1: 1.50e-01, valid acc: 2.50e-01, valid cm: [[ 2  0  2 10]
#  [ 4  0  0 10]
#  [ 0  0  0 14]
#  [ 0  1  1 12]]
# speechbrain.utils.epoch_loop - Going into epoch 20
# speechbrain.nnet.schedulers - Changing lr from 4.4e-05 to 4.7e-05
# speechbrain.utils.train_logger - epoch: 20, lr: 4.17e-05 - train loss: 1.37 - valid loss: 1.38, valid f1: 1.52e-01, valid acc: 2.50e-01, valid cm: [[ 2  0  2 10]
#  [ 4  0  1  9]
#  [ 0  0  0 14]
#  [ 0  1  1 12]]
# speechbrain.utils.epoch_loop - Going into epoch 21
# speechbrain.nnet.schedulers - Changing lr from 6.7e-05 to 6.9e-05
# speechbrain.utils.train_logger - epoch: 21, lr: 6.39e-05 - train loss: 1.38 - valid loss: 1.38, valid f1: 1.51e-01, valid acc: 2.50e-01, valid cm: [[ 2  0  2 10]
#  [ 5  0  1  8]
#  [ 0  0  0 14]
#  [ 0  1  1 12]]
# speechbrain.utils.epoch_loop - Going into epoch 22
# speechbrain.nnet.schedulers - Changing lr from 8.9e-05 to 9.2e-05
# speechbrain.utils.train_logger - epoch: 22, lr: 8.61e-05 - train loss: 1.38 - valid loss: 1.38, valid f1: 1.85e-01, valid acc: 2.68e-01, valid cm: [[ 2  0  2 10]
#  [ 4  1  1  8]
#  [ 0  0  0 14]
#  [ 0  1  1 12]]
# speechbrain.utils.epoch_loop - Going into epoch 23
# speechbrain.nnet.schedulers - Changing lr from 8.9e-05 to 8.6e-05
# speechbrain.utils.train_logger - epoch: 23, lr: 9.17e-05 - train loss: 1.37 - valid loss: 1.38, valid f1: 2.14e-01, valid acc: 2.86e-01, valid cm: [[ 2  0  2 10]
#  [ 4  2  1  7]
#  [ 1  0  0 13]
#  [ 0  1  1 12]]
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/single-fold-example/BNCI2014001/leave-one-session-out/sub-001/1test/save/CKPT+2024-03-25+00-34-46+00
# speechbrain.utils.epoch_loop - Going into epoch 24
# speechbrain.nnet.schedulers - Changing lr from 6.7e-05 to 6.4e-05
# speechbrain.utils.train_logger - epoch: 24, lr: 6.94e-05 - train loss: 1.36 - valid loss: 1.38, valid f1: 2.32e-01, valid acc: 2.86e-01, valid cm: [[ 2  0  2 10]
#  [ 4  2  1  7]
#  [ 1  0  1 12]
#  [ 1  1  1 11]]
# speechbrain.utils.epoch_loop - Going into epoch 25
# speechbrain.nnet.schedulers - Changing lr from 4.4e-05 to 4.2e-05
# speechbrain.utils.train_logger - epoch: 25, lr: 4.72e-05 - train loss: 1.37 - valid loss: 1.38, valid f1: 2.44e-01, valid acc: 2.86e-01, valid cm: [[ 3  0  2  9]
#  [ 4  2  1  7]
#  [ 1  0  1 12]
#  [ 2  1  1 10]]
# speechbrain.utils.epoch_loop - Going into epoch 26
# speechbrain.nnet.schedulers - Changing lr from 2.2e-05 to 1.9e-05
# speechbrain.utils.train_logger - epoch: 26, lr: 2.50e-05 - train loss: 1.37 - valid loss: 1.38, valid f1: 2.69e-01, valid acc: 3.04e-01, valid cm: [[ 3  0  3  8]
#  [ 4  2  1  7]
#  [ 1  0  2 11]
#  [ 2  1  1 10]]
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/single-fold-example/BNCI2014001/leave-one-session-out/sub-001/1test/save/CKPT+2024-03-25+00-34-50+00
# speechbrain.utils.epoch_loop - Going into epoch 27
# speechbrain.nnet.schedulers - Changing lr from 1e-08 to 2.8e-06
# speechbrain.utils.train_logger - epoch: 27, lr: 2.79e-06 - train loss: 1.36 - valid loss: 1.38, valid f1: 2.59e-01, valid acc: 2.86e-01, valid cm: [[ 3  0  3  8]
#  [ 4  2  1  7]
#  [ 1  0  2 11]
#  [ 2  1  2  9]]
# speechbrain.utils.epoch_loop - Going into epoch 28
# speechbrain.nnet.schedulers - Changing lr from 2.2e-05 to 2.5e-05
# speechbrain.utils.train_logger - epoch: 28, lr: 1.95e-05 - train loss: 1.36 - valid loss: 1.38, valid f1: 2.58e-01, valid acc: 2.86e-01, valid cm: [[ 3  0  3  8]
#  [ 5  2  1  6]
#  [ 1  0  2 11]
#  [ 2  1  2  9]]
# speechbrain.utils.epoch_loop - Going into epoch 29
# speechbrain.nnet.schedulers - Changing lr from 4.4e-05 to 4.7e-05
# speechbrain.utils.train_logger - epoch: 29, lr: 4.17e-05 - train loss: 1.36 - valid loss: 1.38, valid f1: 2.80e-01, valid acc: 3.04e-01, valid cm: [[ 3  0  3  8]
#  [ 5  2  1  6]
#  [ 1  0  3 10]
#  [ 2  1  2  9]]
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/single-fold-example/BNCI2014001/leave-one-session-out/sub-001/1test/save/CKPT+2024-03-25+00-34-55+00
# speechbrain.utils.epoch_loop - Going into epoch 30
# speechbrain.nnet.schedulers - Changing lr from 6.7e-05 to 6.9e-05
# speechbrain.utils.train_logger - epoch: 30, lr: 6.39e-05 - train loss: 1.37 - valid loss: 1.37, valid f1: 2.79e-01, valid acc: 3.04e-01, valid cm: [[ 3  0  4  7]
#  [ 5  2  1  6]
#  [ 1  0  3 10]
#  [ 2  1  2  9]]
# speechbrain.utils.epoch_loop - Going into epoch 31
# speechbrain.nnet.schedulers - Changing lr from 8.9e-05 to 9.2e-05
# speechbrain.utils.train_logger - epoch: 31, lr: 8.61e-05 - train loss: 1.38 - valid loss: 1.37, valid f1: 2.79e-01, valid acc: 3.04e-01, valid cm: [[ 3  0  5  6]
#  [ 5  2  2  5]
#  [ 1  0  3 10]
#  [ 2  1  2  9]]
# speechbrain.utils.epoch_loop - Going into epoch 32
# speechbrain.nnet.schedulers - Changing lr from 8.9e-05 to 8.6e-05
# speechbrain.utils.train_logger - epoch: 32, lr: 9.17e-05 - train loss: 1.38 - valid loss: 1.37, valid f1: 2.57e-01, valid acc: 2.86e-01, valid cm: [[ 2  1  5  6]
#  [ 5  2  2  5]
#  [ 1  0  3 10]
#  [ 2  1  2  9]]
# speechbrain.utils.epoch_loop - Going into epoch 33
# speechbrain.nnet.schedulers - Changing lr from 6.7e-05 to 6.4e-05
# speechbrain.utils.train_logger - epoch: 33, lr: 6.94e-05 - train loss: 1.35 - valid loss: 1.37, valid f1: 2.37e-01, valid acc: 2.68e-01, valid cm: [[ 2  1  5  6]
#  [ 5  2  2  5]
#  [ 1  1  2 10]
#  [ 2  1  2  9]]
# speechbrain.utils.epoch_loop - Going into epoch 34
# speechbrain.nnet.schedulers - Changing lr from 4.4e-05 to 4.2e-05
# speechbrain.utils.train_logger - epoch: 34, lr: 4.72e-05 - train loss: 1.36 - valid loss: 1.37, valid f1: 2.37e-01, valid acc: 2.68e-01, valid cm: [[ 2  1  5  6]
#  [ 5  2  2  5]
#  [ 1  1  2 10]
#  [ 2  1  2  9]]
# speechbrain.utils.epoch_loop - Going into epoch 35
# speechbrain.nnet.schedulers - Changing lr from 2.2e-05 to 1.9e-05
# speechbrain.utils.train_logger - epoch: 35, lr: 2.50e-05 - train loss: 1.37 - valid loss: 1.37, valid f1: 2.34e-01, valid acc: 2.50e-01, valid cm: [[2 1 6 5]
#  [5 2 2 5]
#  [1 1 3 9]
#  [3 1 3 7]]
# speechbrain.utils.epoch_loop - Going into epoch 36
# speechbrain.nnet.schedulers - Changing lr from 1e-08 to 2.8e-06
# speechbrain.utils.train_logger - epoch: 36, lr: 2.79e-06 - train loss: 1.35 - valid loss: 1.37, valid f1: 2.33e-01, valid acc: 2.50e-01, valid cm: [[2 2 6 4]
#  [5 2 2 5]
#  [1 1 3 9]
#  [3 1 3 7]]
# speechbrain.utils.epoch_loop - Going into epoch 37
# speechbrain.nnet.schedulers - Changing lr from 2.2e-05 to 2.5e-05
# speechbrain.utils.train_logger - epoch: 37, lr: 1.95e-05 - train loss: 1.38 - valid loss: 1.37, valid f1: 2.33e-01, valid acc: 2.50e-01, valid cm: [[2 2 6 4]
#  [5 2 2 5]
#  [1 1 3 9]
#  [3 1 3 7]]
# speechbrain.utils.epoch_loop - Going into epoch 38
# speechbrain.nnet.schedulers - Changing lr from 4.4e-05 to 4.7e-05
# speechbrain.utils.train_logger - epoch: 38, lr: 4.17e-05 - train loss: 1.36 - valid loss: 1.37, valid f1: 2.51e-01, valid acc: 2.68e-01, valid cm: [[2 2 6 4]
#  [5 2 2 5]
#  [1 1 4 8]
#  [3 1 3 7]]
# speechbrain.utils.epoch_loop - Going into epoch 39
# speechbrain.nnet.schedulers - Changing lr from 6.7e-05 to 6.9e-05
# speechbrain.utils.train_logger - epoch: 39, lr: 6.39e-05 - train loss: 1.36 - valid loss: 1.37, valid f1: 2.51e-01, valid acc: 2.68e-01, valid cm: [[2 2 6 4]
#  [5 2 2 5]
#  [1 1 4 8]
#  [3 1 3 7]]
# speechbrain.utils.epoch_loop - Going into epoch 40
# speechbrain.nnet.schedulers - Changing lr from 8.9e-05 to 9.2e-05
# speechbrain.utils.train_logger - epoch: 40, lr: 8.61e-05 - train loss: 1.36 - valid loss: 1.37, valid f1: 2.51e-01, valid acc: 2.68e-01, valid cm: [[2 3 6 3]
#  [5 2 2 5]
#  [1 1 4 8]
#  [3 1 3 7]]
# speechbrain.utils.epoch_loop - Going into epoch 41
# speechbrain.nnet.schedulers - Changing lr from 8.9e-05 to 8.6e-05
# speechbrain.utils.train_logger - epoch: 41, lr: 9.17e-05 - train loss: 1.34 - valid loss: 1.37, valid f1: 2.54e-01, valid acc: 2.68e-01, valid cm: [[2 3 6 3]
#  [5 2 2 5]
#  [1 1 5 7]
#  [3 1 4 6]]
# speechbrain.utils.epoch_loop - Going into epoch 42
# speechbrain.nnet.schedulers - Changing lr from 6.7e-05 to 6.4e-05
# speechbrain.utils.train_logger - epoch: 42, lr: 6.94e-05 - train loss: 1.35 - valid loss: 1.37, valid f1: 2.93e-01, valid acc: 3.04e-01, valid cm: [[2 3 6 3]
#  [5 3 2 4]
#  [1 1 6 6]
#  [3 1 4 6]]
# speechbrain.utils.epoch_loop - Going into epoch 43
# speechbrain.nnet.schedulers - Changing lr from 4.4e-05 to 4.2e-05
# speechbrain.utils.train_logger - epoch: 43, lr: 4.72e-05 - train loss: 1.35 - valid loss: 1.37, valid f1: 2.69e-01, valid acc: 2.86e-01, valid cm: [[2 3 6 3]
#  [5 2 3 4]
#  [1 1 6 6]
#  [3 1 4 6]]
# speechbrain.utils.epoch_loop - Going into epoch 44
# speechbrain.nnet.schedulers - Changing lr from 2.2e-05 to 1.9e-05
# speechbrain.utils.train_logger - epoch: 44, lr: 2.50e-05 - train loss: 1.34 - valid loss: 1.36, valid f1: 2.69e-01, valid acc: 2.86e-01, valid cm: [[2 3 6 3]
#  [5 2 3 4]
#  [1 1 6 6]
#  [3 1 4 6]]
# speechbrain.utils.epoch_loop - Going into epoch 45
# speechbrain.nnet.schedulers - Changing lr from 1e-08 to 2.8e-06
# speechbrain.utils.train_logger - epoch: 45, lr: 2.79e-06 - train loss: 1.36 - valid loss: 1.36, valid f1: 2.69e-01, valid acc: 2.86e-01, valid cm: [[2 3 6 3]
#  [5 2 3 4]
#  [1 1 6 6]
#  [3 1 4 6]]
# speechbrain.utils.epoch_loop - Going into epoch 46
# speechbrain.nnet.schedulers - Changing lr from 2.2e-05 to 2.5e-05
# speechbrain.utils.train_logger - epoch: 46, lr: 1.95e-05 - train loss: 1.36 - valid loss: 1.36, valid f1: 2.84e-01, valid acc: 3.04e-01, valid cm: [[2 3 6 3]
#  [5 2 3 4]
#  [1 0 7 6]
#  [3 1 4 6]]
# speechbrain.utils.epoch_loop - Going into epoch 47
# speechbrain.nnet.schedulers - Changing lr from 4.4e-05 to 4.7e-05
# speechbrain.utils.train_logger - epoch: 47, lr: 4.17e-05 - train loss: 1.34 - valid loss: 1.36, valid f1: 3.05e-01, valid acc: 3.21e-01, valid cm: [[3 3 5 3]
#  [5 2 3 4]
#  [1 0 7 6]
#  [3 1 4 6]]
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/single-fold-example/BNCI2014001/leave-one-session-out/sub-001/1test/save/CKPT+2024-03-25+00-35-21+00
# speechbrain.utils.epoch_loop - Going into epoch 48
# speechbrain.nnet.schedulers - Changing lr from 6.7e-05 to 6.9e-05
# speechbrain.utils.train_logger - epoch: 48, lr: 6.39e-05 - train loss: 1.35 - valid loss: 1.36, valid f1: 3.05e-01, valid acc: 3.21e-01, valid cm: [[3 3 5 3]
#  [5 2 3 4]
#  [1 0 7 6]
#  [3 1 4 6]]
# speechbrain.utils.epoch_loop - Going into epoch 49
# speechbrain.nnet.schedulers - Changing lr from 8.9e-05 to 9.2e-05
# speechbrain.utils.train_logger - epoch: 49, lr: 8.61e-05 - train loss: 1.34 - valid loss: 1.36, valid f1: 3.05e-01, valid acc: 3.21e-01, valid cm: [[3 3 5 3]
#  [5 2 3 4]
#  [1 0 7 6]
#  [3 1 4 6]]
# speechbrain.utils.epoch_loop - Going into epoch 50
# speechbrain.nnet.schedulers - Changing lr from 8.9e-05 to 8.6e-05
# speechbrain.utils.train_logger - epoch: 50, lr: 9.17e-05 - train loss: 1.35 - valid loss: 1.36, valid f1: 3.28e-01, valid acc: 3.39e-01, valid cm: [[3 3 5 3]
#  [4 3 3 4]
#  [1 0 7 6]
#  [3 1 4 6]]
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/single-fold-example/BNCI2014001/leave-one-session-out/sub-001/1test/save/CKPT+2024-03-25+00-35-25+00
# speechbrain.utils.checkpoints - Loading a checkpoint from results/single-fold-example/BNCI2014001/leave-one-session-out/sub-001/1test/save/CKPT+2024-03-25+00-35-25+00
# speechbrain.utils.train_logger - epoch loaded: 50 - test loss: 1.38, test f1: 2.62e-01, test acc: 3.02e-01, test cm: [[23  2  9 38]
#  [22  7  7 36]
#  [12  0  8 52]
#  [ 9  2 12 49]]
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/single-fold-example/BNCI2014001/leave-one-session-out/sub-001/1test/save/CKPT+2024-03-25+00-35-27+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/single-fold-example/BNCI2014001/leave-one-session-out/sub-001/1test/save/CKPT+2024-03-25+00-34-46+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/single-fold-example/BNCI2014001/leave-one-session-out/sub-001/1test/save/CKPT+2024-03-25+00-34-50+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/single-fold-example/BNCI2014001/leave-one-session-out/sub-001/1test/save/CKPT+2024-03-25+00-34-24+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/single-fold-example/BNCI2014001/leave-one-session-out/sub-001/1test/save/CKPT+2024-03-25+00-34-55+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/single-fold-example/BNCI2014001/leave-one-session-out/sub-001/1test/save/CKPT+2024-03-25+00-35-21+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/single-fold-example/BNCI2014001/leave-one-session-out/sub-001/1test/save/CKPT+2024-03-25+00-34-17+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/single-fold-example/BNCI2014001/leave-one-session-out/sub-001/1test/save/CKPT+2024-03-25+00-35-25+00
# speechbrain.utils.checkpoints - Loading a checkpoint from results/single-fold-example/BNCI2014001/leave-one-session-out/sub-001/1test/save/CKPT+2024-03-25+00-35-27+00
# speechbrain.utils.train_logger - epoch loaded: 50 - test loss: 2.51e-01, test f1: 2.62e-01, test acc: 3.04e-01, test cm: [[ 4  0  1  9]
#  [ 5  2  1  6]
#  [ 1  0  1 12]
#  [ 2  1  1 10]]

# %% [markdown]
# ### Run a complete experiment by looping over the entire dataset

# %%
# !./run_experiments.sh --hparams ../../../example_hyperparams.yaml \
--data_folder 'data/BNCI2014001'\
--cached_data_folder 'data/' \
--output_folder 'results/full-experiment/BNCI2014001' \
--nsbj 9 --nsess 2 --nruns 1 --train_mode 'leave-one-session-out' \
--number_of_epochs 50 \
--device 'cpu'
# Out:
# hparams: ../../../example_hyperparams.yaml
# data_folder: data/BNCI2014001
# cached_data_folder: data/
# output_folder: results/full-experiment/BNCI2014001
# nsbj: 9
# nsess: 2
# seed: 10369
# nruns: 1
# eval_metric: acc
# eval_set: test
# train_mode: leave-one-session-out
# rnd_dir: False
# additional flags: --number_of_epochs 50 --device cpu
# Subject 0
# <frozen importlib._bootstrap>:241: FutureWarning: mne.io.pick.pick_types is deprecated will be removed in 1.6, use documented public API instead. If no appropriate public API exists, please open an issue on GitHub.
# <frozen importlib._bootstrap>:241: FutureWarning: mne.io.pick.pick_channels_regexp is deprecated will be removed in 1.6, use documented public API instead. If no appropriate public API exists, please open an issue on GitHub.
# <frozen importlib._bootstrap>:241: FutureWarning: mne.io.pick.channel_type is deprecated will be removed in 1.6, use documented public API instead. If no appropriate public API exists, please open an issue on GitHub.
# /Users/quan/.pyenv/versions/3.10.12/lib/python3.10/site-packages/moabb/pipelines/__init__.py:26: ModuleNotFoundError: Tensorflow is not installed. You won't be able to use these MOABB pipelines if you attempt to do so.
#   warn(
# To use the get_shape_from_baseconcar, InputShapeSetterEEG, BraindecodeDatasetLoaderyou need to install `braindecode`.`pip install braindecode` or Please refer to `https://braindecode.org`.
# torchvision is not available - cannot save figures
# SpeechBrain could not find any working torchaudio backend. Audio files may fail to load. Follow this link for instructions and troubleshooting: https://pytorch.org/audio/stable/index.html
# SpeechBrain could not find any working torchaudio backend. Audio files may fail to load. Follow this link for instructions and troubleshooting: https://pytorch.org/audio/stable/index.html
# BNCI2014001 has been renamed to BNCI2014_001. BNCI2014001 will be removed in version 1.1.
# The dataset class name 'BNCI2014001' must be an abbreviation of its code 'BNCI2014-001'. See moabb.datasets.base.is_abbrev for more information.
# Prepare dataset iterators...
# Using cached dataset at: data/MOABB_pickled/BNCI2014-001/0125_001-040/sub-001.pkl
# Skipping data saving, a cached dataset was found at data/MOABB_pickled/BNCI2014-001/0125_001-040/sub-001.pkl
# Session/sessions used as training and validation set: ['1test']
# Session used as test set: ['0train']
# Validation indices: [288, 307, 320, 348, 367, 390, 412, 439, 463, 482, 510, 529, 557, 574, 289, 300, 324, 351, 376, 406, 423, 445, 461, 485, 505, 531, 545, 568, 295, 316, 330, 359, 377, 396, 414, 440, 470, 484, 508, 528, 565, 575, 297, 306, 334, 358, 372, 401, 418, 442, 454, 489, 503, 530, 549, 572]
# Sampling all channels available: ['Fz', 'FC3', 'FC1', 'FCz', 'FC2', 'FC4', 'C5', 'C3', 'C1', 'Cz', 'C2', 'C4', 'C6', 'CP3', 'CP1', 'CPz', 'CP2', 'CP4', 'P1', 'Pz', 'P2', 'POz']
# Sampling all channels available: ['Fz', 'FC3', 'FC1', 'FCz', 'FC2', 'FC4', 'C5', 'C3', 'C1', 'Cz', 'C2', 'C4', 'C6', 'CP3', 'CP1', 'CPz', 'CP2', 'CP4', 'P1', 'Pz', 'P2', 'POz']
# Sampling all channels available: ['Fz', 'FC3', 'FC1', 'FCz', 'FC2', 'FC4', 'C5', 'C3', 'C1', 'Cz', 'C2', 'C4', 'C6', 'CP3', 'CP1', 'CPz', 'CP2', 'CP4', 'P1', 'Pz', 'P2', 'POz']
# BNCI2014001 has been renamed to BNCI2014_001. BNCI2014001 will be removed in version 1.1.
# The dataset class name 'BNCI2014001' must be an abbreviation of its code 'BNCI2014-001'. See moabb.datasets.base.is_abbrev for more information.
# speechbrain.core - Beginning experiment!
# speechbrain.core - Experiment folder: results/full-experiment/BNCI2014001/run1/10369/leave-one-session-out/sub-001/0train
# __main__ - Experiment directory: results/full-experiment/BNCI2014001/run1/10369/leave-one-session-out/sub-001/0train
# __main__ - Input shape: torch.Size([500, 22, 1])
# __main__ - Training set avg value: 2.61933692513594e-08
# __main__ - Number of examples: 232 (training), 56 (validation), 288 (test)
# speechbrain.core - Gradscaler enabled: False. Using precision: fp32.
# speechbrain.core - MOABBBrain Model Statistics:
# * Total Number of Trainable Parameters: 2.4k
# * Total Number of Parameters: 2.4k
# * Trainable Parameters represent 100.0000% of the total size.
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# EEGNet                                   [1, 4]                    --
# ├─Sequential: 1-1                        [1, 15, 1, 16]            --
# │    └─Conv2d: 2-1                       [1, 499, 22, 8]           --
# │    │    └─Conv2d: 3-1                  [1, 8, 499, 22]           496
# │    └─BatchNorm2d: 2-2                  [1, 499, 22, 8]           --
# │    │    └─BatchNorm2d: 3-2             [1, 8, 22, 499]           16
# │    └─Conv2d: 2-3                       [1, 499, 1, 16]           --
# │    │    └─Conv2d: 3-3                  [1, 16, 499, 1]           352
# │    └─BatchNorm2d: 2-4                  [1, 499, 1, 16]           --
# │    │    └─BatchNorm2d: 3-4             [1, 16, 1, 499]           32
# │    └─ELU: 2-5                          [1, 499, 1, 16]           --
# │    └─Pooling2d: 2-6                    [1, 124, 1, 16]           --
# │    │    └─AvgPool2d: 3-5               [1, 16, 124, 1]           --
# │    └─Dropout: 2-7                      [1, 124, 1, 16]           --
# │    └─Conv2d: 2-8                       [1, 123, 1, 16]           --
# │    │    └─Conv2d: 3-6                  [1, 16, 123, 1]           256
# │    └─Conv2d: 2-9                       [1, 123, 1, 16]           --
# │    │    └─Conv2d: 3-7                  [1, 16, 123, 1]           256
# │    └─BatchNorm2d: 2-10                 [1, 123, 1, 16]           --
# │    │    └─BatchNorm2d: 3-8             [1, 16, 1, 123]           32
# │    └─ELU: 2-11                         [1, 123, 1, 16]           --
# │    └─Pooling2d: 2-12                   [1, 15, 1, 16]            --
# │    │    └─AvgPool2d: 3-9               [1, 16, 15, 1]            --
# │    └─Dropout: 2-13                     [1, 15, 1, 16]            --
# ├─Sequential: 1-2                        [1, 4]                    --
# │    └─Flatten: 2-14                     [1, 240]                  --
# │    └─Linear: 2-15                      [1, 4]                    --
# │    │    └─Linear: 3-10                 [1, 4]                    964
# │    └─LogSoftmax: 2-16                  [1, 4]                    --
# ==========================================================================================
# Total params: 2,404
# Trainable params: 2,404
# Non-trainable params: 0
# Total mult-adds (M): 5.68
# ==========================================================================================
# Input size (MB): 0.04
# Forward/backward pass size (MB): 1.58
# Params size (MB): 0.01
# Estimated Total Size (MB): 1.63
# ==========================================================================================
# speechbrain.utils.epoch_loop - Going into epoch 1
# speechbrain.nnet.schedulers - Changing lr from 2.2e-05 to 2.5e-05
# speechbrain.utils.train_logger - epoch: 1, lr: 1.95e-05 - train loss: 1.39 - valid loss: 1.39, valid f1: 2.03e-01, valid acc: 2.14e-01, valid cm: [[5 0 8 1]
#  [6 3 4 1]
#  [6 2 3 3]
#  [4 6 3 1]]
# speechbrain.utils.epoch_loop - Going into epoch 2
# speechbrain.nnet.schedulers - Changing lr from 4.4e-05 to 4.7e-05
# speechbrain.utils.train_logger - epoch: 2, lr: 4.17e-05 - train loss: 1.39 - valid loss: 1.39, valid f1: 1.87e-01, valid acc: 1.96e-01, valid cm: [[3 2 9 0]
#  [5 3 6 0]
#  [5 2 4 3]
#  [2 7 4 1]]
# speechbrain.utils.epoch_loop - Going into epoch 3
# speechbrain.nnet.schedulers - Changing lr from 6.7e-05 to 6.9e-05
# speechbrain.utils.train_logger - epoch: 3, lr: 6.39e-05 - train loss: 1.39 - valid loss: 1.39, valid f1: 1.87e-01, valid acc: 1.96e-01, valid cm: [[3 5 6 0]
#  [4 3 7 0]
#  [5 2 4 3]
#  [2 7 4 1]]
# speechbrain.utils.epoch_loop - Going into epoch 4
# speechbrain.nnet.schedulers - Changing lr from 8.9e-05 to 9.2e-05
# speechbrain.utils.train_logger - epoch: 4, lr: 8.61e-05 - train loss: 1.39 - valid loss: 1.39, valid f1: 1.34e-01, valid acc: 1.61e-01, valid cm: [[1 6 7 0]
#  [3 4 7 0]
#  [4 3 4 3]
#  [2 9 3 0]]
# speechbrain.utils.epoch_loop - Going into epoch 5
# speechbrain.nnet.schedulers - Changing lr from 8.9e-05 to 8.6e-05
# speechbrain.utils.train_logger - epoch: 5, lr: 9.17e-05 - train loss: 1.39 - valid loss: 1.39, valid f1: 1.46e-01, valid acc: 1.79e-01, valid cm: [[1 7 6 0]
#  [3 4 7 0]
#  [3 4 5 2]
#  [2 9 3 0]]
# speechbrain.utils.epoch_loop - Going into epoch 6
# speechbrain.nnet.schedulers - Changing lr from 6.7e-05 to 6.4e-05
# speechbrain.utils.train_logger - epoch: 6, lr: 6.94e-05 - train loss: 1.39 - valid loss: 1.39, valid f1: 1.45e-01, valid acc: 1.79e-01, valid cm: [[ 1  7  6  0]
#  [ 3  5  6  0]
#  [ 3  5  4  2]
#  [ 2 10  2  0]]
# speechbrain.utils.epoch_loop - Going into epoch 7
# speechbrain.nnet.schedulers - Changing lr from 4.4e-05 to 4.2e-05
# speechbrain.utils.train_logger - epoch: 7, lr: 4.72e-05 - train loss: 1.39 - valid loss: 1.39, valid f1: 1.33e-01, valid acc: 1.79e-01, valid cm: [[ 0  8  6  0]
#  [ 3  6  5  0]
#  [ 3  6  4  1]
#  [ 2 10  2  0]]
# speechbrain.utils.epoch_loop - Going into epoch 8
# speechbrain.nnet.schedulers - Changing lr from 2.2e-05 to 1.9e-05
# speechbrain.utils.train_logger - epoch: 8, lr: 2.50e-05 - train loss: 1.39 - valid loss: 1.39, valid f1: 1.45e-01, valid acc: 1.96e-01, valid cm: [[ 0  8  6  0]
#  [ 2  5  7  0]
#  [ 2  5  6  1]
#  [ 2 10  2  0]]
# speechbrain.utils.epoch_loop - Going into epoch 9
# speechbrain.nnet.schedulers - Changing lr from 1e-08 to 2.8e-06
# speechbrain.utils.train_logger - epoch: 9, lr: 2.79e-06 - train loss: 1.40 - valid loss: 1.39, valid f1: 1.45e-01, valid acc: 1.96e-01, valid cm: [[ 0  8  6  0]
#  [ 2  5  7  0]
#  [ 2  5  6  1]
#  [ 2 10  2  0]]
# speechbrain.utils.epoch_loop - Going into epoch 10
# speechbrain.nnet.schedulers - Changing lr from 2.2e-05 to 2.5e-05
# speechbrain.utils.train_logger - epoch: 10, lr: 1.95e-05 - train loss: 1.39 - valid loss: 1.39, valid f1: 1.45e-01, valid acc: 1.96e-01, valid cm: [[ 0  8  6  0]
#  [ 2  5  7  0]
#  [ 2  5  6  1]
#  [ 2 10  2  0]]
# speechbrain.utils.epoch_loop - Going into epoch 11
# speechbrain.nnet.schedulers - Changing lr from 4.4e-05 to 4.7e-05
# speechbrain.utils.train_logger - epoch: 11, lr: 4.17e-05 - train loss: 1.40 - valid loss: 1.39, valid f1: 1.45e-01, valid acc: 1.96e-01, valid cm: [[ 0  8  6  0]
#  [ 2  5  7  0]
#  [ 2  5  6  1]
#  [ 2 10  2  0]]
# speechbrain.utils.epoch_loop - Going into epoch 12
# speechbrain.nnet.schedulers - Changing lr from 6.7e-05 to 6.9e-05
# speechbrain.utils.train_logger - epoch: 12, lr: 6.39e-05 - train loss: 1.39 - valid loss: 1.39, valid f1: 1.45e-01, valid acc: 1.96e-01, valid cm: [[ 0  8  6  0]
#  [ 2  5  7  0]
#  [ 2  5  6  1]
#  [ 2 10  2  0]]
# speechbrain.utils.epoch_loop - Going into epoch 13
# speechbrain.nnet.schedulers - Changing lr from 8.9e-05 to 9.2e-05
# speechbrain.utils.train_logger - epoch: 13, lr: 8.61e-05 - train loss: 1.39 - valid loss: 1.39, valid f1: 1.44e-01, valid acc: 1.96e-01, valid cm: [[0 7 7 0]
#  [2 5 7 0]
#  [2 5 6 1]
#  [2 9 3 0]]
# speechbrain.utils.epoch_loop - Going into epoch 14
# speechbrain.nnet.schedulers - Changing lr from 8.9e-05 to 8.6e-05
# speechbrain.utils.train_logger - epoch: 14, lr: 9.17e-05 - train loss: 1.39 - valid loss: 1.39, valid f1: 1.93e-01, valid acc: 2.32e-01, valid cm: [[2 6 6 0]
#  [2 5 7 0]
#  [2 5 6 1]
#  [2 9 3 0]]
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/full-experiment/BNCI2014001/run1/10369/leave-one-session-out/sub-001/0train/save/CKPT+2024-03-25+00-39-46+00
# speechbrain.utils.epoch_loop - Going into epoch 15
# speechbrain.nnet.schedulers - Changing lr from 6.7e-05 to 6.4e-05
# speechbrain.utils.train_logger - epoch: 15, lr: 6.94e-05 - train loss: 1.40 - valid loss: 1.39, valid f1: 2.25e-01, valid acc: 2.50e-01, valid cm: [[2 6 6 0]
#  [2 5 7 0]
#  [2 5 6 1]
#  [1 7 5 1]]
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/full-experiment/BNCI2014001/run1/10369/leave-one-session-out/sub-001/0train/save/CKPT+2024-03-25+00-39-47+00
# speechbrain.utils.epoch_loop - Going into epoch 16
# speechbrain.nnet.schedulers - Changing lr from 4.4e-05 to 4.2e-05
# speechbrain.utils.train_logger - epoch: 16, lr: 4.72e-05 - train loss: 1.39 - valid loss: 1.39, valid f1: 2.25e-01, valid acc: 2.50e-01, valid cm: [[2 6 6 0]
#  [2 5 7 0]
#  [2 5 6 1]
#  [1 7 5 1]]
# speechbrain.utils.epoch_loop - Going into epoch 17
# speechbrain.nnet.schedulers - Changing lr from 2.2e-05 to 1.9e-05
# speechbrain.utils.train_logger - epoch: 17, lr: 2.50e-05 - train loss: 1.38 - valid loss: 1.39, valid f1: 2.25e-01, valid acc: 2.50e-01, valid cm: [[2 6 6 0]
#  [2 5 7 0]
#  [2 5 6 1]
#  [1 7 5 1]]
# speechbrain.utils.epoch_loop - Going into epoch 18
# speechbrain.nnet.schedulers - Changing lr from 1e-08 to 2.8e-06
# speechbrain.utils.train_logger - epoch: 18, lr: 2.79e-06 - train loss: 1.38 - valid loss: 1.39, valid f1: 2.12e-01, valid acc: 2.32e-01, valid cm: [[2 6 6 0]
#  [2 5 7 0]
#  [2 5 5 2]
#  [2 7 4 1]]
# speechbrain.utils.epoch_loop - Going into epoch 19
# speechbrain.nnet.schedulers - Changing lr from 2.2e-05 to 2.5e-05
# speechbrain.utils.train_logger - epoch: 19, lr: 1.95e-05 - train loss: 1.38 - valid loss: 1.39, valid f1: 2.12e-01, valid acc: 2.32e-01, valid cm: [[2 6 6 0]
#  [2 5 7 0]
#  [2 5 5 2]
#  [2 7 4 1]]
# speechbrain.utils.epoch_loop - Going into epoch 20
# speechbrain.nnet.schedulers - Changing lr from 4.4e-05 to 4.7e-05
# speechbrain.utils.train_logger - epoch: 20, lr: 4.17e-05 - train loss: 1.38 - valid loss: 1.39, valid f1: 1.84e-01, valid acc: 1.96e-01, valid cm: [[2 6 6 0]
#  [2 4 7 1]
#  [3 5 4 2]
#  [2 7 4 1]]
# speechbrain.utils.epoch_loop - Going into epoch 21
# speechbrain.nnet.schedulers - Changing lr from 6.7e-05 to 6.9e-05
# speechbrain.utils.train_logger - epoch: 21, lr: 6.39e-05 - train loss: 1.39 - valid loss: 1.39, valid f1: 1.84e-01, valid acc: 1.96e-01, valid cm: [[2 6 6 0]
#  [2 4 7 1]
#  [3 5 4 2]
#  [2 7 4 1]]
# speechbrain.utils.epoch_loop - Going into epoch 22
# speechbrain.nnet.schedulers - Changing lr from 8.9e-05 to 9.2e-05
# speechbrain.utils.train_logger - epoch: 22, lr: 8.61e-05 - train loss: 1.38 - valid loss: 1.39, valid f1: 2.05e-01, valid acc: 2.14e-01, valid cm: [[3 5 6 0]
#  [2 4 7 1]
#  [3 5 4 2]
#  [2 7 4 1]]
# speechbrain.utils.epoch_loop - Going into epoch 23
# speechbrain.nnet.schedulers - Changing lr from 8.9e-05 to 8.6e-05
# speechbrain.utils.train_logger - epoch: 23, lr: 9.17e-05 - train loss: 1.39 - valid loss: 1.39, valid f1: 2.04e-01, valid acc: 2.14e-01, valid cm: [[3 5 6 0]
#  [3 4 6 1]
#  [3 5 4 2]
#  [2 7 4 1]]
# speechbrain.utils.epoch_loop - Going into epoch 24
# speechbrain.nnet.schedulers - Changing lr from 6.7e-05 to 6.4e-05
# speechbrain.utils.train_logger - epoch: 24, lr: 6.94e-05 - train loss: 1.39 - valid loss: 1.39, valid f1: 2.04e-01, valid acc: 2.14e-01, valid cm: [[3 5 6 0]
#  [3 4 6 1]
#  [3 5 4 2]
#  [2 7 4 1]]
# speechbrain.utils.epoch_loop - Going into epoch 25
# speechbrain.nnet.schedulers - Changing lr from 4.4e-05 to 4.2e-05
# speechbrain.utils.train_logger - epoch: 25, lr: 4.72e-05 - train loss: 1.38 - valid loss: 1.39, valid f1: 1.88e-01, valid acc: 1.96e-01, valid cm: [[3 5 6 0]
#  [4 3 6 1]
#  [3 5 4 2]
#  [2 7 4 1]]
# speechbrain.utils.epoch_loop - Going into epoch 26
# speechbrain.nnet.schedulers - Changing lr from 2.2e-05 to 1.9e-05
# speechbrain.utils.train_logger - epoch: 26, lr: 2.50e-05 - train loss: 1.38 - valid loss: 1.39, valid f1: 1.74e-01, valid acc: 1.79e-01, valid cm: [[3 5 6 0]
#  [4 3 6 1]
#  [3 5 3 3]
#  [2 7 4 1]]
# speechbrain.utils.epoch_loop - Going into epoch 27
# speechbrain.nnet.schedulers - Changing lr from 1e-08 to 2.8e-06
# speechbrain.utils.train_logger - epoch: 27, lr: 2.79e-06 - train loss: 1.38 - valid loss: 1.39, valid f1: 1.74e-01, valid acc: 1.79e-01, valid cm: [[3 5 6 0]
#  [4 3 6 1]
#  [3 5 3 3]
#  [2 7 4 1]]
# speechbrain.utils.epoch_loop - Going into epoch 28
# speechbrain.nnet.schedulers - Changing lr from 2.2e-05 to 2.5e-05
# speechbrain.utils.train_logger - epoch: 28, lr: 1.95e-05 - train loss: 1.38 - valid loss: 1.39, valid f1: 1.74e-01, valid acc: 1.79e-01, valid cm: [[3 5 6 0]
#  [4 3 6 1]
#  [3 5 3 3]
#  [2 7 4 1]]
# speechbrain.utils.epoch_loop - Going into epoch 29
# speechbrain.nnet.schedulers - Changing lr from 4.4e-05 to 4.7e-05
# speechbrain.utils.train_logger - epoch: 29, lr: 4.17e-05 - train loss: 1.37 - valid loss: 1.39, valid f1: 1.74e-01, valid acc: 1.79e-01, valid cm: [[3 5 6 0]
#  [4 3 6 1]
#  [3 5 3 3]
#  [2 7 4 1]]
# speechbrain.utils.epoch_loop - Going into epoch 30
# speechbrain.nnet.schedulers - Changing lr from 6.7e-05 to 6.9e-05
# speechbrain.utils.train_logger - epoch: 30, lr: 6.39e-05 - train loss: 1.39 - valid loss: 1.38, valid f1: 1.74e-01, valid acc: 1.79e-01, valid cm: [[3 5 6 0]
#  [4 3 6 1]
#  [3 5 3 3]
#  [2 7 4 1]]
# speechbrain.utils.epoch_loop - Going into epoch 31
# speechbrain.nnet.schedulers - Changing lr from 8.9e-05 to 9.2e-05
# speechbrain.utils.train_logger - epoch: 31, lr: 8.61e-05 - train loss: 1.38 - valid loss: 1.38, valid f1: 1.74e-01, valid acc: 1.79e-01, valid cm: [[3 4 7 0]
#  [4 3 6 1]
#  [3 5 3 3]
#  [2 7 4 1]]
# speechbrain.utils.epoch_loop - Going into epoch 32
# speechbrain.nnet.schedulers - Changing lr from 8.9e-05 to 8.6e-05
# speechbrain.utils.train_logger - epoch: 32, lr: 9.17e-05 - train loss: 1.37 - valid loss: 1.38, valid f1: 1.74e-01, valid acc: 1.79e-01, valid cm: [[3 4 7 0]
#  [4 3 6 1]
#  [3 5 3 3]
#  [2 7 4 1]]
# speechbrain.utils.epoch_loop - Going into epoch 33
# speechbrain.nnet.schedulers - Changing lr from 6.7e-05 to 6.4e-05
# speechbrain.utils.train_logger - epoch: 33, lr: 6.94e-05 - train loss: 1.36 - valid loss: 1.38, valid f1: 1.75e-01, valid acc: 1.79e-01, valid cm: [[3 4 7 0]
#  [4 3 6 1]
#  [3 5 3 3]
#  [1 7 5 1]]
# speechbrain.utils.epoch_loop - Going into epoch 34
# speechbrain.nnet.schedulers - Changing lr from 4.4e-05 to 4.2e-05
# speechbrain.utils.train_logger - epoch: 34, lr: 4.72e-05 - train loss: 1.37 - valid loss: 1.38, valid f1: 2.00e-01, valid acc: 1.96e-01, valid cm: [[3 4 7 0]
#  [4 3 6 1]
#  [3 5 3 3]
#  [1 7 4 2]]
# speechbrain.utils.epoch_loop - Going into epoch 35
# speechbrain.nnet.schedulers - Changing lr from 2.2e-05 to 1.9e-05
# speechbrain.utils.train_logger - epoch: 35, lr: 2.50e-05 - train loss: 1.37 - valid loss: 1.38, valid f1: 2.13e-01, valid acc: 2.14e-01, valid cm: [[3 4 7 0]
#  [4 4 5 1]
#  [3 5 3 3]
#  [2 7 3 2]]
# speechbrain.utils.epoch_loop - Going into epoch 36
# speechbrain.nnet.schedulers - Changing lr from 1e-08 to 2.8e-06
# speechbrain.utils.train_logger - epoch: 36, lr: 2.79e-06 - train loss: 1.37 - valid loss: 1.38, valid f1: 2.13e-01, valid acc: 2.14e-01, valid cm: [[3 4 7 0]
#  [4 4 5 1]
#  [3 5 3 3]
#  [2 7 3 2]]
# speechbrain.utils.epoch_loop - Going into epoch 37
# speechbrain.nnet.schedulers - Changing lr from 2.2e-05 to 2.5e-05
# speechbrain.utils.train_logger - epoch: 37, lr: 1.95e-05 - train loss: 1.37 - valid loss: 1.38, valid f1: 2.13e-01, valid acc: 2.14e-01, valid cm: [[3 4 7 0]
#  [5 4 4 1]
#  [3 5 3 3]
#  [2 7 3 2]]
# speechbrain.utils.epoch_loop - Going into epoch 38
# speechbrain.nnet.schedulers - Changing lr from 4.4e-05 to 4.7e-05
# speechbrain.utils.train_logger - epoch: 38, lr: 4.17e-05 - train loss: 1.39 - valid loss: 1.38, valid f1: 2.13e-01, valid acc: 2.14e-01, valid cm: [[3 4 7 0]
#  [5 4 4 1]
#  [3 5 3 3]
#  [2 7 3 2]]
# speechbrain.utils.epoch_loop - Going into epoch 39
# speechbrain.nnet.schedulers - Changing lr from 6.7e-05 to 6.9e-05
# speechbrain.utils.train_logger - epoch: 39, lr: 6.39e-05 - train loss: 1.38 - valid loss: 1.38, valid f1: 2.12e-01, valid acc: 2.14e-01, valid cm: [[3 4 6 1]
#  [5 4 4 1]
#  [3 5 3 3]
#  [2 7 3 2]]
# speechbrain.utils.epoch_loop - Going into epoch 40
# speechbrain.nnet.schedulers - Changing lr from 8.9e-05 to 9.2e-05
# speechbrain.utils.train_logger - epoch: 40, lr: 8.61e-05 - train loss: 1.38 - valid loss: 1.38, valid f1: 2.12e-01, valid acc: 2.14e-01, valid cm: [[3 4 6 1]
#  [5 4 4 1]
#  [3 5 3 3]
#  [2 7 3 2]]
# speechbrain.utils.epoch_loop - Going into epoch 41
# speechbrain.nnet.schedulers - Changing lr from 8.9e-05 to 8.6e-05
# speechbrain.utils.train_logger - epoch: 41, lr: 9.17e-05 - train loss: 1.37 - valid loss: 1.38, valid f1: 2.13e-01, valid acc: 2.14e-01, valid cm: [[3 4 6 1]
#  [5 4 4 1]
#  [3 6 3 2]
#  [1 7 4 2]]
# speechbrain.utils.epoch_loop - Going into epoch 42
# speechbrain.nnet.schedulers - Changing lr from 6.7e-05 to 6.4e-05
# speechbrain.utils.train_logger - epoch: 42, lr: 6.94e-05 - train loss: 1.37 - valid loss: 1.38, valid f1: 2.13e-01, valid acc: 2.14e-01, valid cm: [[3 4 6 1]
#  [5 4 4 1]
#  [3 6 3 2]
#  [2 6 4 2]]
# speechbrain.utils.epoch_loop - Going into epoch 43
# speechbrain.nnet.schedulers - Changing lr from 4.4e-05 to 4.2e-05
# speechbrain.utils.train_logger - epoch: 43, lr: 4.72e-05 - train loss: 1.36 - valid loss: 1.38, valid f1: 2.27e-01, valid acc: 2.32e-01, valid cm: [[3 4 6 1]
#  [5 5 3 1]
#  [3 6 3 2]
#  [2 6 4 2]]
# speechbrain.utils.epoch_loop - Going into epoch 44
# speechbrain.nnet.schedulers - Changing lr from 2.2e-05 to 1.9e-05
# speechbrain.utils.train_logger - epoch: 44, lr: 2.50e-05 - train loss: 1.37 - valid loss: 1.38, valid f1: 2.27e-01, valid acc: 2.32e-01, valid cm: [[3 4 6 1]
#  [5 5 3 1]
#  [3 6 3 2]
#  [2 6 4 2]]
# speechbrain.utils.epoch_loop - Going into epoch 45
# speechbrain.nnet.schedulers - Changing lr from 1e-08 to 2.8e-06
# speechbrain.utils.train_logger - epoch: 45, lr: 2.79e-06 - train loss: 1.38 - valid loss: 1.38, valid f1: 2.27e-01, valid acc: 2.32e-01, valid cm: [[3 4 6 1]
#  [5 5 3 1]
#  [3 6 3 2]
#  [2 6 4 2]]
# speechbrain.utils.epoch_loop - Going into epoch 46
# speechbrain.nnet.schedulers - Changing lr from 2.2e-05 to 2.5e-05
# speechbrain.utils.train_logger - epoch: 46, lr: 1.95e-05 - train loss: 1.38 - valid loss: 1.38, valid f1: 2.26e-01, valid acc: 2.32e-01, valid cm: [[3 4 5 2]
#  [5 5 3 1]
#  [3 5 3 3]
#  [2 6 4 2]]
# speechbrain.utils.epoch_loop - Going into epoch 47
# speechbrain.nnet.schedulers - Changing lr from 4.4e-05 to 4.7e-05
# speechbrain.utils.train_logger - epoch: 47, lr: 4.17e-05 - train loss: 1.37 - valid loss: 1.38, valid f1: 2.26e-01, valid acc: 2.32e-01, valid cm: [[3 4 5 2]
#  [5 5 3 1]
#  [3 5 3 3]
#  [2 6 4 2]]
# speechbrain.utils.epoch_loop - Going into epoch 48
# speechbrain.nnet.schedulers - Changing lr from 6.7e-05 to 6.9e-05
# speechbrain.utils.train_logger - epoch: 48, lr: 6.39e-05 - train loss: 1.36 - valid loss: 1.38, valid f1: 2.26e-01, valid acc: 2.32e-01, valid cm: [[3 4 5 2]
#  [5 5 3 1]
#  [3 5 3 3]
#  [2 6 4 2]]
# speechbrain.utils.epoch_loop - Going into epoch 49
# speechbrain.nnet.schedulers - Changing lr from 8.9e-05 to 9.2e-05
# speechbrain.utils.train_logger - epoch: 49, lr: 8.61e-05 - train loss: 1.36 - valid loss: 1.38, valid f1: 2.68e-01, valid acc: 2.68e-01, valid cm: [[3 3 5 3]
#  [5 5 3 1]
#  [3 4 3 4]
#  [2 4 4 4]]
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/full-experiment/BNCI2014001/run1/10369/leave-one-session-out/sub-001/0train/save/CKPT+2024-03-25+00-40-36+00
# speechbrain.utils.epoch_loop - Going into epoch 50
# speechbrain.nnet.schedulers - Changing lr from 8.9e-05 to 8.6e-05
# speechbrain.utils.train_logger - epoch: 50, lr: 9.17e-05 - train loss: 1.37 - valid loss: 1.38, valid f1: 2.69e-01, valid acc: 2.68e-01, valid cm: [[3 3 6 2]
#  [5 5 3 1]
#  [3 4 3 4]
#  [2 4 4 4]]
# speechbrain.utils.checkpoints - Loading a checkpoint from results/full-experiment/BNCI2014001/run1/10369/leave-one-session-out/sub-001/0train/save/CKPT+2024-03-25+00-40-36+00
# speechbrain.utils.train_logger - epoch loaded: 49 - test loss: 1.39, test f1: 2.25e-01, test acc: 2.67e-01, test cm: [[12 28 32  0]
#  [10 35 26  1]
#  [11 28 29  4]
#  [13 33 25  1]]
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/full-experiment/BNCI2014001/run1/10369/leave-one-session-out/sub-001/0train/save/CKPT+2024-03-25+00-40-38+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/full-experiment/BNCI2014001/run1/10369/leave-one-session-out/sub-001/0train/save/CKPT+2024-03-25+00-39-47+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/full-experiment/BNCI2014001/run1/10369/leave-one-session-out/sub-001/0train/save/CKPT+2024-03-25+00-40-36+00
# speechbrain.utils.checkpoints - Deleted checkpoint in results/full-experiment/BNCI2014001/run1/10369/leave-one-session-out/sub-001/0train/save/CKPT+2024-03-25+00-39-46+00
# speechbrain.utils.checkpoints - Loading a checkpoint from results/full-experiment/BNCI2014001/run1/10369/leave-one-session-out/sub-001/0train/save/CKPT+2024-03-25+00-40-38+00
# speechbrain.utils.train_logger - epoch loaded: 49 - test loss: 2.52e-01, test f1: 2.11e-01, test acc: 2.32e-01, test cm: [[2 5 7 0]
#  [2 4 7 1]
#  [2 5 6 1]
#  [1 7 5 1]]
# Subject 1
# <frozen importlib._bootstrap>:241: FutureWarning: mne.io.pick.pick_types is deprecated will be removed in 1.6, use documented public API instead. If no appropriate public API exists, please open an issue on GitHub.
# <frozen importlib._bootstrap>:241: FutureWarning: mne.io.pick.pick_channels_regexp is deprecated will be removed in 1.6, use documented public API instead. If no appropriate public API exists, please open an issue on GitHub.
# <frozen importlib._bootstrap>:241: FutureWarning: mne.io.pick.channel_type is deprecated will be removed in 1.6, use documented public API instead. If no appropriate public API exists, please open an issue on GitHub.
# /Users/quan/.pyenv/versions/3.10.12/lib/python3.10/site-packages/moabb/pipelines/__init__.py:26: ModuleNotFoundError: Tensorflow is not installed. You won't be able to use these MOABB pipelines if you attempt to do so.
#   warn(
# To use the get_shape_from_baseconcar, InputShapeSetterEEG, BraindecodeDatasetLoaderyou need to install `braindecode`.`pip install braindecode` or Please refer to `https://braindecode.org`.
# torchvision is not available - cannot save figures
# SpeechBrain could not find any working torchaudio backend. Audio files may fail to load. Follow this link for instructions and troubleshooting: https://pytorch.org/audio/stable/index.html
# SpeechBrain could not find any working torchaudio backend. Audio files may fail to load. Follow this link for instructions and troubleshooting: https://pytorch.org/audio/stable/index.html
# BNCI2014001 has been renamed to BNCI2014_001. BNCI2014001 will be removed in version 1.1.
# The dataset class name 'BNCI2014001' must be an abbreviation of its code 'BNCI2014-001'. See moabb.datasets.base.is_abbrev for more information.
# Prepare dataset iterators...
# Choosing from all possible events
# Downloading data from 'http://bnci-horizon-2020.eu/database/data-sets/001-2014/A02T.mat' to file '/Users/quan/Documents/Concordia Classes/COMP432/speechbrain_moabb_project/benchmarks/benchmarks/MOABB/data/BNCI2014001/MNE-bnci-data/database/data-sets/001-2014/A02T.mat'.
# /Users/quan/.pyenv/versions/3.10.12/lib/python3.10/site-packages/urllib3/connectionpool.py:1061: InsecureRequestWarning: Unverified HTTPS request is being made to host 'lampx.tugraz.at'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# 100%|██████████████████████████████████████| 43.1M/43.1M [00:00<00:00, 235GB/s]
# SHA256 hash of downloaded file: 5ddd5cb520b1692c3ba1363f48d98f58f0e46f3699ee50d749947950fc39db27
# Use this value as the 'known_hash' argument of 'pooch.retrieve' to ensure that the file hasn't changed if it is downloaded again in the future.
# Downloading data from 'http://bnci-horizon-2020.eu/database/data-sets/001-2014/A02E.mat' to file '/Users/quan/Documents/Concordia Classes/COMP432/speechbrain_moabb_project/benchmarks/benchmarks/MOABB/data/BNCI2014001/MNE-bnci-data/database/data-sets/001-2014/A02E.mat'.
# /Users/quan/.pyenv/versions/3.10.12/lib/python3.10/site-packages/urllib3/connectionpool.py:1061: InsecureRequestWarning: Unverified HTTPS request is being made to host 'lampx.tugraz.at'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# 100%|██████████████████████████████████████| 44.2M/44.2M [00:00<00:00, 293GB/s]
# SHA256 hash of downloaded file: d63c454005d3a9b41d8440629482e855afc823339bdd0b5721842a7ee9cc7b12
# Use this value as the 'known_hash' argument of 'pooch.retrieve' to ensure that the file hasn't changed if it is downloaded again in the future.
# Saving the dataset at data/MOABB_pickled/BNCI2014-001/0125_001-040/sub-002.pkl
# Session/sessions used as training and validation set: ['1test']
# Session used as test set: ['0train']
# Validation indices: [288, 307, 320, 348, 367, 390, 412, 439, 463, 482, 510, 529, 557, 574, 289, 300, 324, 351, 376, 406, 423, 445, 461, 485, 505, 531, 545, 568, 295, 316, 330, 359, 377, 396, 414, 440, 470, 484, 508, 528, 565, 575, 297, 306, 334, 358, 372, 401, 418, 442, 454, 489, 503, 530, 549, 572]
# Sampling all channels available: ['Fz', 'FC3', 'FC1', 'FCz', 'FC2', 'FC4', 'C5', 'C3', 'C1', 'Cz', 'C2', 'C4', 'C6', 'CP3', 'CP1', 'CPz', 'CP2', 'CP4', 'P1', 'Pz', 'P2', 'POz']
# Sampling all channels available: ['Fz', 'FC3', 'FC1', 'FCz', 'FC2', 'FC4', 'C5', 'C3', 'C1', 'Cz', 'C2', 'C4', 'C6', 'CP3', 'CP1', 'CPz', 'CP2', 'CP4', 'P1', 'Pz', 'P2', 'POz']
# Sampling all channels available: ['Fz', 'FC3', 'FC1', 'FCz', 'FC2', 'FC4', 'C5', 'C3', 'C1', 'Cz', 'C2', 'C4', 'C6', 'CP3', 'CP1', 'CPz', 'CP2', 'CP4', 'P1', 'Pz', 'P2', 'POz']
# BNCI2014001 has been renamed to BNCI2014_001. BNCI2014001 will be removed in version 1.1.
# The dataset class name 'BNCI2014001' must be an abbreviation of its code 'BNCI2014-001'. See moabb.datasets.base.is_abbrev for more information.
# speechbrain.core - Beginning experiment!
# speechbrain.core - Experiment folder: results/full-experiment/BNCI2014001/run1/10369/leave-one-session-out/sub-002/0train
# __main__ - Experiment directory: results/full-experiment/BNCI2014001/run1/10369/leave-one-session-out/sub-002/0train
# __main__ - Input shape: torch.Size([500, 22, 1])
# __main__ - Training set avg value: 7.3154131641217646e-09
# __main__ - Number of examples: 232 (training), 56 (validation), 288 (test)
# speechbrain.core - Gradscaler enabled: False. Using precision: fp32.
# speechbrain.core - MOABBBrain Model Statistics:
# * Total Number of Trainable Parameters: 2.4k
# * Total Number of Parameters: 2.4k
# * Trainable Parameters represent 100.0000% of the total size.
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# EEGNet                                   [1, 4]                    --
# ├─Sequential: 1-1                        [1, 15, 1, 16]            --
# │    └─Conv2d: 2-1                       [1, 499, 22, 8]           --
# │    │    └─Conv2d: 3-1                  [1, 8, 499, 22]           496
# │    └─BatchNorm2d: 2-2                  [1, 499, 22, 8]           --
# │    │    └─BatchNorm2d: 3-2             [1, 8, 22, 499]           16
# │    └─Conv2d: 2-3                       [1, 499, 1, 16]           --
# │    │    └─Conv2d: 3-3                  [1, 16, 499, 1]           352
# │    └─BatchNorm2d: 2-4                  [1, 499, 1, 16]           --
# │    │    └─BatchNorm2d: 3-4             [1, 16, 1, 499]           32
# │    └─ELU: 2-5                          [1, 499, 1, 16]           --
# │    └─Pooling2d: 2-6                    [1, 124, 1, 16]           --
# │    │    └─AvgPool2d: 3-5               [1, 16, 124, 1]           --
# │    └─Dropout: 2-7                      [1, 124, 1, 16]           --
# │    └─Conv2d: 2-8                       [1, 123, 1, 16]           --
# │    │    └─Conv2d: 3-6                  [1, 16, 123, 1]           256
# │    └─Conv2d: 2-9                       [1, 123, 1, 16]           --
# │    │    └─Conv2d: 3-7                  [1, 16, 123, 1]           256
# │    └─BatchNorm2d: 2-10                 [1, 123, 1, 16]           --
# │    │    └─BatchNorm2d: 3-8             [1, 16, 1, 123]           32
# │    └─ELU: 2-11                         [1, 123, 1, 16]           --
# │    └─Pooling2d: 2-12                   [1, 15, 1, 16]            --
# │    │    └─AvgPool2d: 3-9               [1, 16, 15, 1]            --
# │    └─Dropout: 2-13                     [1, 15, 1, 16]            --
# ├─Sequential: 1-2                        [1, 4]                    --
# │    └─Flatten: 2-14                     [1, 240]                  --
# │    └─Linear: 2-15                      [1, 4]                    --
# │    │    └─Linear: 3-10                 [1, 4]                    964
# │    └─LogSoftmax: 2-16                  [1, 4]                    --
# ==========================================================================================
# Total params: 2,404
# Trainable params: 2,404
# Non-trainable params: 0
# Total mult-adds (M): 5.68
# ==========================================================================================
# Input size (MB): 0.04
# Forward/backward pass size (MB): 1.58
# Params size (MB): 0.01
# Estimated Total Size (MB): 1.63
# ==========================================================================================
# speechbrain.utils.epoch_loop - Going into epoch 1
# speechbrain.nnet.schedulers - Changing lr from 2.2e-05 to 2.5e-05
# speechbrain.utils.train_logger - epoch: 1, lr: 1.95e-05 - train loss: 1.39 - valid loss: 1.39, valid f1: 1.57e-01, valid acc: 1.96e-01, valid cm: [[ 5  8  1  0]
#  [ 6  5  1  2]
#  [ 3 10  1  0]
#  [ 8  4  2  0]]
# speechbrain.utils.epoch_loop - Going into epoch 2
# speechbrain.nnet.schedulers - Changing lr from 4.4e-05 to 4.7e-05
# speechbrain.utils.train_logger - epoch: 2, lr: 4.17e-05 - train loss: 1.39 - valid loss: 1.39, valid f1: 1.40e-01, valid acc: 1.96e-01, valid cm: [[ 4  9  1  0]
#  [ 5  7  1  1]
#  [ 1 13  0  0]
#  [ 4  8  2  0]]
# speechbrain.utils.epoch_loop - Going into epoch 3
# speechbrain.nnet.schedulers - Changing lr from 6.7e-05 to 6.9e-05
# speechbrain.utils.train_logger - epoch: 3, lr: 6.39e-05 - train loss: 1.39 - valid loss: 1.39, valid f1: 1.24e-01, valid acc: 1.96e-01, valid cm: [[ 2 12  0  0]
#  [ 3  9  1  1]
#  [ 1 13  0  0]
#  [ 1 11  2  0]]
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/full-experiment/BNCI2014001/run1/10369/leave-one-session-out/sub-002/0train/save/CKPT+2024-03-25+00-40-56+00
# speechbrain.utils.epoch_loop - Going into epoch 4
# speechbrain.nnet.schedulers - Changing lr from 8.9e-05 to 9.2e-05
# speechbrain.utils.train_logger - epoch: 4, lr: 8.61e-05 - train loss: 1.40 - valid loss: 1.39, valid f1: 1.16e-01, valid acc: 2.14e-01, valid cm: [[ 1 13  0  0]
#  [ 1 11  1  1]
#  [ 1 13  0  0]
#  [ 1 11  2  0]]
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/full-experiment/BNCI2014001/run1/10369/leave-one-session-out/sub-002/0train/save/CKPT+2024-03-25+00-40-58+00
# speechbrain.utils.epoch_loop - Going into epoch 5
# speechbrain.nnet.schedulers - Changing lr from 8.9e-05 to 8.6e-05
# speechbrain.utils.train_logger - epoch: 5, lr: 9.17e-05 - train loss: 1.40 - valid loss: 1.39, valid f1: 8.59e-02, valid acc: 1.96e-01, valid cm: [[ 0 14  0  0]
#  [ 1 11  1  1]
#  [ 1 13  0  0]
#  [ 0 12  2  0]]
# speechbrain.utils.epoch_loop - Going into epoch 6
# speechbrain.nnet.schedulers - Changing lr from 6.7e-05 to 6.4e-05
# speechbrain.utils.train_logger - epoch: 6, lr: 6.94e-05 - train loss: 1.40 - valid loss: 1.39, valid f1: 8.59e-02, valid acc: 1.96e-01, valid cm: [[ 0 14  0  0]
#  [ 1 11  1  1]
#  [ 1 13  0  0]
#  [ 0 12  2  0]]
# speechbrain.utils.epoch_loop - Going into epoch 7
# speechbrain.nnet.schedulers - Changing lr from 4.4e-05 to 4.2e-05
# speechbrain.utils.train_logger - epoch: 7, lr: 4.72e-05 - train loss: 1.38 - valid loss: 1.39, valid f1: 8.59e-02, valid acc: 1.96e-01, valid cm: [[ 0 14  0  0]
#  [ 1 11  1  1]
#  [ 1 13  0  0]
#  [ 0 12  2  0]]
# speechbrain.utils.epoch_loop - Going into epoch 8
# speechbrain.nnet.schedulers - Changing lr from 2.2e-05 to 1.9e-05
# speechbrain.utils.train_logger - epoch: 8, lr: 2.50e-05 - train loss: 1.39 - valid loss: 1.39, valid f1: 1.14e-01, valid acc: 2.14e-01, valid cm: [[ 0 14  0  0]
#  [ 1 11  1  1]
#  [ 0 13  1  0]
#  [ 0 11  3  0]]
# speechbrain.utils.epoch_loop - Going into epoch 9
# speechbrain.nnet.schedulers - Changing lr from 1e-08 to 2.8e-06
# speechbrain.utils.train_logger - epoch: 9, lr: 2.79e-06 - train loss: 1.38 - valid loss: 1.39, valid f1: 1.14e-01, valid acc: 2.14e-01, valid cm: [[ 0 14  0  0]
#  [ 1 11  1  1]
#  [ 0 13  1  0]
#  [ 0 11  3  0]]
# speechbrain.utils.epoch_loop - Going into epoch 10
# speechbrain.nnet.schedulers - Changing lr from 2.2e-05 to 2.5e-05
# speechbrain.utils.train_logger - epoch: 10, lr: 1.95e-05 - train loss: 1.38 - valid loss: 1.39, valid f1: 1.14e-01, valid acc: 2.14e-01, valid cm: [[ 0 14  0  0]
#  [ 1 11  1  1]
#  [ 0 13  1  0]
#  [ 0 11  3  0]]
# speechbrain.utils.epoch_loop - Going into epoch 11
# speechbrain.nnet.schedulers - Changing lr from 4.4e-05 to 4.7e-05
# speechbrain.utils.train_logger - epoch: 11, lr: 4.17e-05 - train loss: 1.39 - valid loss: 1.39, valid f1: 1.20e-01, valid acc: 2.32e-01, valid cm: [[ 0 14  0  0]
#  [ 1 12  1  0]
#  [ 0 13  1  0]
#  [ 0 11  3  0]]
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/full-experiment/BNCI2014001/run1/10369/leave-one-session-out/sub-002/0train/save/CKPT+2024-03-25+00-41-08+00
# speechbrain.utils.epoch_loop - Going into epoch 12
# speechbrain.nnet.schedulers - Changing lr from 6.7e-05 to 6.9e-05
# speechbrain.utils.train_logger - epoch: 12, lr: 6.39e-05 - train loss: 1.39 - valid loss: 1.39, valid f1: 1.06e-01, valid acc: 1.96e-01, valid cm: [[ 0 14  0  0]
#  [ 1 10  2  1]
#  [ 0 13  1  0]
#  [ 0 11  3  0]]
# speechbrain.utils.epoch_loop - Going into epoch 13
# speechbrain.nnet.schedulers - Changing lr from 8.9e-05 to 9.2e-05
# speechbrain.utils.train_logger - epoch: 13, lr: 8.61e-05 - train loss: 1.38 - valid loss: 1.39, valid f1: 1.06e-01, valid acc: 1.96e-01, valid cm: [[ 0 14  0  0]
#  [ 1 10  2  1]
#  [ 0 13  1  0]
#  [ 0 11  3  0]]
# speechbrain.utils.epoch_loop - Going into epoch 14
# speechbrain.nnet.schedulers - Changing lr from 8.9e-05 to 8.6e-05
# speechbrain.utils.train_logger - epoch: 14, lr: 9.17e-05 - train loss: 1.39 - valid loss: 1.39, valid f1: 1.06e-01, valid acc: 1.96e-01, valid cm: [[ 0 14  0  0]
#  [ 2 10  2  0]
#  [ 0 13  1  0]
#  [ 0 11  3  0]]
# speechbrain.utils.epoch_loop - Going into epoch 15
# speechbrain.nnet.schedulers - Changing lr from 6.7e-05 to 6.4e-05
# speechbrain.utils.train_logger - epoch: 15, lr: 6.94e-05 - train loss: 1.37 - valid loss: 1.39, valid f1: 1.06e-01, valid acc: 1.96e-01, valid cm: [[ 0 14  0  0]
#  [ 2 10  2  0]
#  [ 0 13  1  0]
#  [ 0 11  3  0]]
# speechbrain.utils.epoch_loop - Going into epoch 16
# speechbrain.nnet.schedulers - Changing lr from 4.4e-05 to 4.2e-05
# speechbrain.utils.train_logger - epoch: 16, lr: 4.72e-05 - train loss: 1.39 - valid loss: 1.39, valid f1: 1.36e-01, valid acc: 2.14e-01, valid cm: [[ 1 13  0  0]
#  [ 2 10  2  0]
#  [ 0 13  1  0]
#  [ 0 11  3  0]]
# speechbrain.utils.epoch_loop - Going into epoch 17
# speechbrain.nnet.schedulers - Changing lr from 2.2e-05 to 1.9e-05
# speechbrain.utils.train_logger - epoch: 17, lr: 2.50e-05 - train loss: 1.39 - valid loss: 1.39, valid f1: 1.64e-01, valid acc: 2.32e-01, valid cm: [[ 2 11  1  0]
#  [ 2 10  2  0]
#  [ 0 13  1  0]
#  [ 0 11  3  0]]
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/full-experiment/BNCI2014001/run1/10369/leave-one-session-out/sub-002/0train/save/CKPT+2024-03-25+00-41-17+00
# speechbrain.utils.epoch_loop - Going into epoch 18
# speechbrain.nnet.schedulers - Changing lr from 1e-08 to 2.8e-06
# speechbrain.utils.train_logger - epoch: 18, lr: 2.79e-06 - train loss: 1.38 - valid loss: 1.39, valid f1: 1.57e-01, valid acc: 2.14e-01, valid cm: [[ 2 11  1  0]
#  [ 2  9  3  0]
#  [ 0 13  1  0]
#  [ 0  9  5  0]]
# speechbrain.utils.epoch_loop - Going into epoch 19
# speechbrain.nnet.schedulers - Changing lr from 2.2e-05 to 2.5e-05
# speechbrain.utils.train_logger - epoch: 19, lr: 1.95e-05 - train loss: 1.38 - valid loss: 1.39, valid f1: 1.55e-01, valid acc: 2.14e-01, valid cm: [[ 2 11  1  0]
#  [ 2  9  3  0]
#  [ 0 13  1  0]
#  [ 1  8  5  0]]
# speechbrain.utils.epoch_loop - Going into epoch 20
# speechbrain.nnet.schedulers - Changing lr from 4.4e-05 to 4.7e-05
# speechbrain.utils.train_logger - epoch: 20, lr: 4.17e-05 - train loss: 1.37 - valid loss: 1.39, valid f1: 1.54e-01, valid acc: 2.14e-01, valid cm: [[ 2 11  1  0]
#  [ 2  9  3  0]
#  [ 0 13  1  0]
#  [ 2  7  5  0]]
# speechbrain.utils.epoch_loop - Going into epoch 21
# speechbrain.nnet.schedulers - Changing lr from 6.7e-05 to 6.9e-05
# speechbrain.utils.train_logger - epoch: 21, lr: 6.39e-05 - train loss: 1.38 - valid loss: 1.39, valid f1: 1.77e-01, valid acc: 2.32e-01, valid cm: [[ 3 10  1  0]
#  [ 2  9  3  0]
#  [ 0 13  1  0]
#  [ 2  7  5  0]]
# speechbrain.utils.epoch_loop - Going into epoch 22
# speechbrain.nnet.schedulers - Changing lr from 8.9e-05 to 9.2e-05
# speechbrain.utils.train_logger - epoch: 22, lr: 8.61e-05 - train loss: 1.39 - valid loss: 1.39, valid f1: 1.75e-01, valid acc: 2.32e-01, valid cm: [[ 3 10  1  0]
#  [ 3  9  2  0]
#  [ 0 13  1  0]
#  [ 2  7  5  0]]
# speechbrain.utils.epoch_loop - Going into epoch 23
# speechbrain.nnet.schedulers - Changing lr from 8.9e-05 to 8.6e-05
# speechbrain.utils.train_logger - epoch: 23, lr: 9.17e-05 - train loss: 1.38 - valid loss: 1.39, valid f1: 1.75e-01, valid acc: 2.32e-01, valid cm: [[ 3 10  1  0]
#  [ 3  9  2  0]
#  [ 0 13  1  0]
#  [ 2  7  5  0]]
# speechbrain.utils.epoch_loop - Going into epoch 24
# speechbrain.nnet.schedulers - Changing lr from 6.7e-05 to 6.4e-05
# speechbrain.utils.train_logger - epoch: 24, lr: 6.94e-05 - train loss: 1.38 - valid loss: 1.39, valid f1: 1.75e-01, valid acc: 2.32e-01, valid cm: [[ 3 10  1  0]
#  [ 3  9  2  0]
#  [ 0 13  1  0]
#  [ 2  7  5  0]]
# speechbrain.utils.epoch_loop - Going into epoch 25
# speechbrain.nnet.schedulers - Changing lr from 4.4e-05 to 4.2e-05
# speechbrain.utils.train_logger - epoch: 25, lr: 4.72e-05 - train loss: 1.38 - valid loss: 1.39, valid f1: 2.17e-01, valid acc: 2.68e-01, valid cm: [[ 4 10  0  0]
#  [ 3  9  2  0]
#  [ 0 12  2  0]
#  [ 2  7  5  0]]
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/full-experiment/BNCI2014001/run1/10369/leave-one-session-out/sub-002/0train/save/CKPT+2024-03-25+00-41-29+00
# speechbrain.utils.epoch_loop - Going into epoch 26
# speechbrain.nnet.schedulers - Changing lr from 2.2e-05 to 1.9e-05
# speechbrain.utils.train_logger - epoch: 26, lr: 2.50e-05 - train loss: 1.38 - valid loss: 1.39, valid f1: 2.15e-01, valid acc: 2.68e-01, valid cm: [[ 4 10  0  0]
#  [ 3  9  2  0]
#  [ 1 11  2  0]
#  [ 2  7  5  0]]
# speechbrain.utils.epoch_loop - Going into epoch 27
# speechbrain.nnet.schedulers - Changing lr from 1e-08 to 2.8e-06
# speechbrain.utils.train_logger - epoch: 27, lr: 2.79e-06 - train loss: 1.38 - valid loss: 1.39, valid f1: 2.15e-01, valid acc: 2.68e-01, valid cm: [[ 4 10  0  0]
#  [ 3  9  2  0]
#  [ 1 11  2  0]
#  [ 2  7  5  0]]
# speechbrain.utils.epoch_loop - Going into epoch 28
# speechbrain.nnet.schedulers - Changing lr from 2.2e-05 to 2.5e-05
# speechbrain.utils.train_logger - epoch: 28, lr: 1.95e-05 - train loss: 1.38 - valid loss: 1.39, valid f1: 2.33e-01, valid acc: 2.86e-01, valid cm: [[ 5  9  0  0]
#  [ 3  9  2  0]
#  [ 1 11  2  0]
#  [ 2  7  5  0]]
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/full-experiment/BNCI2014001/run1/10369/leave-one-session-out/sub-002/0train/save/CKPT+2024-03-25+00-41-33+00
# speechbrain.utils.epoch_loop - Going into epoch 29
# speechbrain.nnet.schedulers - Changing lr from 4.4e-05 to 4.7e-05
# speechbrain.utils.train_logger - epoch: 29, lr: 4.17e-05 - train loss: 1.38 - valid loss: 1.39, valid f1: 2.51e-01, valid acc: 3.04e-01, valid cm: [[ 6  8  0  0]
#  [ 3  9  2  0]
#  [ 1 11  2  0]
#  [ 2  7  5  0]]
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/full-experiment/BNCI2014001/run1/10369/leave-one-session-out/sub-002/0train/save/CKPT+2024-03-25+00-41-34+00
# speechbrain.utils.epoch_loop - Going into epoch 30
# speechbrain.nnet.schedulers - Changing lr from 6.7e-05 to 6.9e-05
# speechbrain.utils.train_logger - epoch: 30, lr: 6.39e-05 - train loss: 1.37 - valid loss: 1.39, valid f1: 2.51e-01, valid acc: 3.04e-01, valid cm: [[ 6  8  0  0]
#  [ 3  9  2  0]
#  [ 1 11  2  0]
#  [ 2  7  5  0]]
# speechbrain.utils.epoch_loop - Going into epoch 31
# speechbrain.nnet.schedulers - Changing lr from 8.9e-05 to 9.2e-05
# speechbrain.utils.train_logger - epoch: 31, lr: 8.61e-05 - train loss: 1.37 - valid loss: 1.39, valid f1: 2.51e-01, valid acc: 3.04e-01, valid cm: [[ 6  8  0  0]
#  [ 3  9  2  0]
#  [ 1 11  2  0]
#  [ 2  7  5  0]]
# speechbrain.utils.epoch_loop - Going into epoch 32
# speechbrain.nnet.schedulers - Changing lr from 8.9e-05 to 8.6e-05
# speechbrain.utils.train_logger - epoch: 32, lr: 9.17e-05 - train loss: 1.37 - valid loss: 1.39, valid f1: 2.40e-01, valid acc: 2.86e-01, valid cm: [[ 6  8  0  0]
#  [ 3  8  3  0]
#  [ 1 11  2  0]
#  [ 2  7  5  0]]
# speechbrain.utils.epoch_loop - Going into epoch 33
# speechbrain.nnet.schedulers - Changing lr from 6.7e-05 to 6.4e-05
# speechbrain.utils.train_logger - epoch: 33, lr: 6.94e-05 - train loss: 1.38 - valid loss: 1.39, valid f1: 2.32e-01, valid acc: 2.68e-01, valid cm: [[ 6  8  0  0]
#  [ 3  7  3  1]
#  [ 1 11  2  0]
#  [ 2  7  5  0]]
# speechbrain.utils.epoch_loop - Going into epoch 34
# speechbrain.nnet.schedulers - Changing lr from 4.4e-05 to 4.2e-05
# speechbrain.utils.train_logger - epoch: 34, lr: 4.72e-05 - train loss: 1.37 - valid loss: 1.39, valid f1: 2.32e-01, valid acc: 2.68e-01, valid cm: [[ 6  8  0  0]
#  [ 3  7  3  1]
#  [ 1 11  2  0]
#  [ 2  7  5  0]]
# speechbrain.utils.epoch_loop - Going into epoch 35
# speechbrain.nnet.schedulers - Changing lr from 2.2e-05 to 1.9e-05
# speechbrain.utils.train_logger - epoch: 35, lr: 2.50e-05 - train loss: 1.37 - valid loss: 1.39, valid f1: 2.33e-01, valid acc: 2.68e-01, valid cm: [[ 6  8  0  0]
#  [ 3  7  2  2]
#  [ 1 11  2  0]
#  [ 2  7  5  0]]
# speechbrain.utils.epoch_loop - Going into epoch 36
# speechbrain.nnet.schedulers - Changing lr from 1e-08 to 2.8e-06
# speechbrain.utils.train_logger - epoch: 36, lr: 2.79e-06 - train loss: 1.38 - valid loss: 1.39, valid f1: 2.33e-01, valid acc: 2.68e-01, valid cm: [[ 6  8  0  0]
#  [ 3  7  2  2]
#  [ 1 11  2  0]
#  [ 2  7  5  0]]
# speechbrain.utils.epoch_loop - Going into epoch 37
# speechbrain.nnet.schedulers - Changing lr from 2.2e-05 to 2.5e-05
# speechbrain.utils.train_logger - epoch: 37, lr: 1.95e-05 - train loss: 1.37 - valid loss: 1.39, valid f1: 2.33e-01, valid acc: 2.68e-01, valid cm: [[ 6  8  0  0]
#  [ 3  7  2  2]
#  [ 1 11  2  0]
#  [ 2  7  5  0]]
# speechbrain.utils.epoch_loop - Going into epoch 38
# speechbrain.nnet.schedulers - Changing lr from 4.4e-05 to 4.7e-05
# speechbrain.utils.train_logger - epoch: 38, lr: 4.17e-05 - train loss: 1.37 - valid loss: 1.39, valid f1: 2.44e-01, valid acc: 2.86e-01, valid cm: [[ 6  8  0  0]
#  [ 3  8  1  2]
#  [ 1 11  2  0]
#  [ 2  7  5  0]]
# speechbrain.utils.epoch_loop - Going into epoch 39
# speechbrain.nnet.schedulers - Changing lr from 6.7e-05 to 6.9e-05
# speechbrain.utils.train_logger - epoch: 39, lr: 6.39e-05 - train loss: 1.38 - valid loss: 1.39, valid f1: 2.44e-01, valid acc: 2.86e-01, valid cm: [[ 6  8  0  0]
#  [ 3  8  1  2]
#  [ 1 11  2  0]
#  [ 2  7  5  0]]
# speechbrain.utils.epoch_loop - Going into epoch 40
# speechbrain.nnet.schedulers - Changing lr from 8.9e-05 to 9.2e-05
# speechbrain.utils.train_logger - epoch: 40, lr: 8.61e-05 - train loss: 1.36 - valid loss: 1.39, valid f1: 2.31e-01, valid acc: 2.68e-01, valid cm: [[ 6  7  1  0]
#  [ 4  7  1  2]
#  [ 1 11  2  0]
#  [ 2  7  5  0]]
# speechbrain.utils.epoch_loop - Going into epoch 41
# speechbrain.nnet.schedulers - Changing lr from 8.9e-05 to 8.6e-05
# speechbrain.utils.train_logger - epoch: 41, lr: 9.17e-05 - train loss: 1.36 - valid loss: 1.39, valid f1: 2.31e-01, valid acc: 2.68e-01, valid cm: [[ 6  7  1  0]
#  [ 4  7  1  2]
#  [ 1 11  2  0]
#  [ 2  7  5  0]]
# speechbrain.utils.epoch_loop - Going into epoch 42
# speechbrain.nnet.schedulers - Changing lr from 6.7e-05 to 6.4e-05
# speechbrain.utils.train_logger - epoch: 42, lr: 6.94e-05 - train loss: 1.36 - valid loss: 1.39, valid f1: 2.31e-01, valid acc: 2.68e-01, valid cm: [[ 6  7  1  0]
#  [ 4  7  1  2]
#  [ 1 11  2  0]
#  [ 2  7  5  0]]
# speechbrain.utils.epoch_loop - Going into epoch 43
# speechbrain.nnet.schedulers - Changing lr from 4.4e-05 to 4.2e-05
# ...
# speechbrain.utils.checkpoints - Deleted checkpoint in results/full-experiment/BNCI2014001/run1/10369/leave-one-session-out/sub-003/1test/save/CKPT+2024-03-25+00-56-22+00
# speechbrain.utils.checkpoints - Loading a checkpoint from results/full-experiment/BNCI2014001/run1/10369/leave-one-session-out/sub-003/1test/save/CKPT+2024-03-25+00-56-31+00
# speechbrain.utils.train_logger - epoch loaded: 46 - test loss: 2.52e-01, test f1: 2.71e-01, test acc: 2.86e-01, test cm: [[7 4 3 0]
#  [1 4 9 0]
#  [4 4 4 2]
#  [4 3 6 1]]
# Subject 3
# <frozen importlib._bootstrap>:241: FutureWarning: mne.io.pick.pick_types is deprecated will be removed in 1.6, use documented public API instead. If no appropriate public API exists, please open an issue on GitHub.
# <frozen importlib._bootstrap>:241: FutureWarning: mne.io.pick.pick_channels_regexp is deprecated will be removed in 1.6, use documented public API instead. If no appropriate public API exists, please open an issue on GitHub.
# <frozen importlib._bootstrap>:241: FutureWarning: mne.io.pick.channel_type is deprecated will be removed in 1.6, use documented public API instead. If no appropriate public API exists, please open an issue on GitHub.
# /Users/quan/.pyenv/versions/3.10.12/lib/python3.10/site-packages/moabb/pipelines/__init__.py:26: ModuleNotFoundError: Tensorflow is not installed. You won't be able to use these MOABB pipelines if you attempt to do so.
#   warn(
# To use the get_shape_from_baseconcar, InputShapeSetterEEG, BraindecodeDatasetLoaderyou need to install `braindecode`.`pip install braindecode` or Please refer to `https://braindecode.org`.
# torchvision is not available - cannot save figures
# SpeechBrain could not find any working torchaudio backend. Audio files may fail to load. Follow this link for instructions and troubleshooting: https://pytorch.org/audio/stable/index.html
# SpeechBrain could not find any working torchaudio backend. Audio files may fail to load. Follow this link for instructions and troubleshooting: https://pytorch.org/audio/stable/index.html
# BNCI2014001 has been renamed to BNCI2014_001. BNCI2014001 will be removed in version 1.1.
# The dataset class name 'BNCI2014001' must be an abbreviation of its code 'BNCI2014-001'. See moabb.datasets.base.is_abbrev for more information.
# Prepare dataset iterators...
# Using cached dataset at: data/MOABB_pickled/BNCI2014-001/0125_001-040/sub-004.pkl
# Skipping data saving, a cached dataset was found at data/MOABB_pickled/BNCI2014-001/0125_001-040/sub-004.pkl
# Session/sessions used as training and validation set: ['0train']
# Session used as test set: ['1test']
# Validation indices: [2, 17, 40, 64, 75, 106, 122, 154, 163, 193, 212, 242, 264, 287, 9, 21, 38, 68, 80, 102, 129, 152, 174, 200, 227, 240, 265, 286, 16, 26, 43, 66, 90, 120, 135, 153, 179, 199, 218, 243, 267, 284, 0, 8, 44, 67, 89, 112, 140, 157, 172, 201, 215, 241, 257, 280]
# Sampling all channels available: ['Fz', 'FC3', 'FC1', 'FCz', 'FC2', 'FC4', 'C5', 'C3', 'C1', 'Cz', 'C2', 'C4', 'C6', 'CP3', 'CP1', 'CPz', 'CP2', 'CP4', 'P1', 'Pz', 'P2', 'POz']
# Sampling all channels available: ['Fz', 'FC3', 'FC1', 'FCz', 'FC2', 'FC4', 'C5', 'C3', 'C1', 'Cz', 'C2', 'C4', 'C6', 'CP3', 'CP1', 'CPz', 'CP2', 'CP4', 'P1', 'Pz', 'P2', 'POz']
# Sampling all channels available: ['Fz', 'FC3', 'FC1', 'FCz', 'FC2', 'FC4', 'C5', 'C3', 'C1', 'Cz', 'C2', 'C4', 'C6', 'CP3', 'CP1', 'CPz', 'CP2', 'CP4', 'P1', 'Pz', 'P2', 'POz']
# BNCI2014001 has been renamed to BNCI2014_001. BNCI2014001 will be removed in version 1.1.
# The dataset class name 'BNCI2014001' must be an abbreviation of its code 'BNCI2014-001'. See moabb.datasets.base.is_abbrev for more information.
# speechbrain.core - Beginning experiment!
# speechbrain.core - Experiment folder: results/full-experiment/BNCI2014001/run1/10369/leave-one-session-out/sub-004/1test
# __main__ - Experiment directory: results/full-experiment/BNCI2014001/run1/10369/leave-one-session-out/sub-004/1test
# __main__ - Input shape: torch.Size([500, 22, 1])
# __main__ - Training set avg value: 2.636610929585004e-10
# __main__ - Number of examples: 232 (training), 56 (validation), 288 (test)
# speechbrain.core - Gradscaler enabled: False. Using precision: fp32.
# speechbrain.core - MOABBBrain Model Statistics:
# * Total Number of Trainable Parameters: 2.4k
# * Total Number of Parameters: 2.4k
# * Trainable Parameters represent 100.0000% of the total size.
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# EEGNet                                   [1, 4]                    --
# ├─Sequential: 1-1                        [1, 15, 1, 16]            --
# │    └─Conv2d: 2-1                       [1, 499, 22, 8]           --
# │    │    └─Conv2d: 3-1                  [1, 8, 499, 22]           496
# │    └─BatchNorm2d: 2-2                  [1, 499, 22, 8]           --
# │    │    └─BatchNorm2d: 3-2             [1, 8, 22, 499]           16
# │    └─Conv2d: 2-3                       [1, 499, 1, 16]           --
# │    │    └─Conv2d: 3-3                  [1, 16, 499, 1]           352
# │    └─BatchNorm2d: 2-4                  [1, 499, 1, 16]           --
# │    │    └─BatchNorm2d: 3-4             [1, 16, 1, 499]           32
# │    └─ELU: 2-5                          [1, 499, 1, 16]           --
# │    └─Pooling2d: 2-6                    [1, 124, 1, 16]           --
# │    │    └─AvgPool2d: 3-5               [1, 16, 124, 1]           --
# │    └─Dropout: 2-7                      [1, 124, 1, 16]           --
# │    └─Conv2d: 2-8                       [1, 123, 1, 16]           --
# │    │    └─Conv2d: 3-6                  [1, 16, 123, 1]           256
# │    └─Conv2d: 2-9                       [1, 123, 1, 16]           --
# │    │    └─Conv2d: 3-7                  [1, 16, 123, 1]           256
# │    └─BatchNorm2d: 2-10                 [1, 123, 1, 16]           --
# │    │    └─BatchNorm2d: 3-8             [1, 16, 1, 123]           32
# │    └─ELU: 2-11                         [1, 123, 1, 16]           --
# │    └─Pooling2d: 2-12                   [1, 15, 1, 16]            --
# │    │    └─AvgPool2d: 3-9               [1, 16, 15, 1]            --
# │    └─Dropout: 2-13                     [1, 15, 1, 16]            --
# ├─Sequential: 1-2                        [1, 4]                    --
# │    └─Flatten: 2-14                     [1, 240]                  --
# │    └─Linear: 2-15                      [1, 4]                    --
# │    │    └─Linear: 3-10                 [1, 4]                    964
# │    └─LogSoftmax: 2-16                  [1, 4]                    --
# ==========================================================================================
# Total params: 2,404
# Trainable params: 2,404
# Non-trainable params: 0
# Total mult-adds (M): 5.68
# ==========================================================================================
# Input size (MB): 0.04
# Forward/backward pass size (MB): 1.58
# Params size (MB): 0.01
# Estimated Total Size (MB): 1.63
# ==========================================================================================
# speechbrain.utils.epoch_loop - Going into epoch 1
# speechbrain.nnet.schedulers - Changing lr from 2.2e-05 to 2.5e-05
# speechbrain.utils.train_logger - epoch: 1, lr: 1.95e-05 - train loss: 1.39 - valid loss: 1.39, valid f1: 2.09e-01, valid acc: 2.32e-01, valid cm: [[6 2 5 1]
#  [5 5 2 2]
#  [9 2 1 2]
#  [5 6 2 1]]
# speechbrain.utils.epoch_loop - Going into epoch 2
# speechbrain.nnet.schedulers - Changing lr from 4.4e-05 to 4.7e-05
# speechbrain.utils.train_logger - epoch: 2, lr: 4.17e-05 - train loss: 1.39 - valid loss: 1.39, valid f1: 2.14e-01, valid acc: 2.32e-01, valid cm: [[5 4 4 1]
#  [5 5 2 2]
#  [6 4 2 2]
#  [3 7 3 1]]
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/full-experiment/BNCI2014001/run1/10369/leave-one-session-out/sub-004/1test/save/CKPT+2024-03-25+00-56-39+00
# speechbrain.utils.epoch_loop - Going into epoch 3
# speechbrain.nnet.schedulers - Changing lr from 6.7e-05 to 6.9e-05
# speechbrain.utils.train_logger - epoch: 3, lr: 6.39e-05 - train loss: 1.39 - valid loss: 1.39, valid f1: 2.26e-01, valid acc: 2.50e-01, valid cm: [[4 5 4 1]
#  [3 7 3 1]
#  [6 4 2 2]
#  [3 7 3 1]]
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/full-experiment/BNCI2014001/run1/10369/leave-one-session-out/sub-004/1test/save/CKPT+2024-03-25+00-56-40+00
# speechbrain.utils.epoch_loop - Going into epoch 4
# speechbrain.nnet.schedulers - Changing lr from 8.9e-05 to 9.2e-05
# speechbrain.utils.train_logger - epoch: 4, lr: 8.61e-05 - train loss: 1.39 - valid loss: 1.39, valid f1: 2.26e-01, valid acc: 2.50e-01, valid cm: [[2 7 4 1]
#  [3 7 3 1]
#  [4 5 4 1]
#  [3 8 2 1]]
# speechbrain.utils.epoch_loop - Going into epoch 5
# speechbrain.nnet.schedulers - Changing lr from 8.9e-05 to 8.6e-05
# speechbrain.utils.train_logger - epoch: 5, lr: 9.17e-05 - train loss: 1.38 - valid loss: 1.39, valid f1: 2.24e-01, valid acc: 2.50e-01, valid cm: [[2 7 5 0]
#  [2 7 4 1]
#  [4 6 4 0]
#  [3 8 2 1]]
# speechbrain.utils.epoch_loop - Going into epoch 6
# speechbrain.nnet.schedulers - Changing lr from 6.7e-05 to 6.4e-05
# speechbrain.utils.train_logger - epoch: 6, lr: 6.94e-05 - train loss: 1.39 - valid loss: 1.39, valid f1: 2.34e-01, valid acc: 2.68e-01, valid cm: [[2 7 5 0]
#  [1 8 5 0]
#  [3 7 4 0]
#  [2 9 2 1]]
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/full-experiment/BNCI2014001/run1/10369/leave-one-session-out/sub-004/1test/save/CKPT+2024-03-25+00-56-44+00
# speechbrain.utils.epoch_loop - Going into epoch 7
# speechbrain.nnet.schedulers - Changing lr from 4.4e-05 to 4.2e-05
# speechbrain.utils.train_logger - epoch: 7, lr: 4.72e-05 - train loss: 1.40 - valid loss: 1.39, valid f1: 2.50e-01, valid acc: 2.86e-01, valid cm: [[2 7 5 0]
#  [1 8 5 0]
#  [2 7 5 0]
#  [2 9 2 1]]
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/full-experiment/BNCI2014001/run1/10369/leave-one-session-out/sub-004/1test/save/CKPT+2024-03-25+00-56-46+00
# speechbrain.utils.epoch_loop - Going into epoch 8
# speechbrain.nnet.schedulers - Changing lr from 2.2e-05 to 1.9e-05
# speechbrain.utils.train_logger - epoch: 8, lr: 2.50e-05 - train loss: 1.39 - valid loss: 1.39, valid f1: 2.50e-01, valid acc: 2.86e-01, valid cm: [[2 7 5 0]
#  [1 8 5 0]
#  [2 7 5 0]
#  [1 9 3 1]]
# speechbrain.utils.epoch_loop - Going into epoch 9
# speechbrain.nnet.schedulers - Changing lr from 1e-08 to 2.8e-06
# speechbrain.utils.train_logger - epoch: 9, lr: 2.79e-06 - train loss: 1.38 - valid loss: 1.39, valid f1: 2.62e-01, valid acc: 3.04e-01, valid cm: [[2 7 5 0]
#  [0 9 5 0]
#  [2 7 5 0]
#  [1 9 3 1]]
# speechbrain.utils.checkpoints - Saved an end-of-epoch checkpoint in results/full-experiment/BNCI2014001/run1/10369/leave-one-session-out/sub-004/1test/save/CKPT+2024-03-25+00-56-49+00
# speechbrain.utils.epoch_loop - Going into epoch 10
# speechbrain.nnet.schedulers - Changing lr from 2.2e-05 to 2.5e-05
# speechbrain.utils.train_logger - epoch: 10, lr: 1.95e-05 - train loss: 1.39 - valid loss: 1.39, valid f1: 2.46e-01, valid acc: 2.86e-01, valid cm: [[2 7 5 0]
#  [0 9 5 0]
#  [2 8 4 0]
#  [1 9 3 1]]
# speechbrain.utils.epoch_loop - Going into epoch 11
# speechbrain.nnet.schedulers - Changing lr from 4.4e-05 to 4.7e-05
# speechbrain.utils.train_logger - epoch: 11, lr: 4.17e-05 - train loss: 1.38 - valid loss: 1.39, valid f1: 2.62e-01, valid acc: 3.04e-01, valid cm: [[2 7 5 0]
#  [0 9 5 0]
#  [2 7 5 0]
#  [1 9 3 1]]
# speechbrain.utils.epoch_loop - Going into epoch 12
# speechbrain.nnet.schedulers - Changing lr from 6.7e-05 to 6.9e-05
# speechbrain.utils.train_logger - epoch: 12, lr: 6.39e-05 - train loss: 1.40 - valid loss: 1.39, valid f1: 2.47e-01, valid acc: 2.86e-01, valid cm: [[2 8 4 0]
#  [0 9 5 0]
#  [1 9 4 0]
#  [1 9 3 1]]
# speechbrain.utils.epoch_loop - Going into epoch 13
# speechbrain.nnet.schedulers - Changing lr from 8.9e-05 to 9.2e-05
# speechbrain.utils.train_logger - epoch: 13, lr: 8.61e-05 - train loss: 1.39 - valid loss: 1.39, valid f1: 2.47e-01, valid acc: 2.86e-01, valid cm: [[2 8 4 0]
#  [0 9 5 0]
#  [1 9 4 0]
#  [1 9 3 1]]
# speechbrain.utils.epoch_loop - Going into epoch 14
# speechbrain.nnet.schedulers - Changing lr from 8.9e-05 to 8.6e-05
# speechbrain.utils.train_logger - epoch: 14, lr: 9.17e-05 - train loss: 1.38 - valid loss: 1.39, valid f1: 2.63e-01, valid acc: 3.04e-01, valid cm: [[2 8 4 0]
#  [0 9 5 0]
#  [1 8 5 0]
#  [1 9 3 1]]
# speechbrain.utils.epoch_loop - Going into epoch 15
# ^C
# speechbrain.core - Exception:
# Traceback (most recent call last):
#   File "/Users/quan/Documents/Concordia Classes/COMP432/speechbrain_moabb_project/benchmarks/benchmarks/MOABB/train.py", line 393, in <module>
#     run_experiment(hparams, run_opts, datasets)
#   File "/Users/quan/Documents/Concordia Classes/COMP432/speechbrain_moabb_project/benchmarks/benchmarks/MOABB/train.py", line 291, in run_experiment
#     brain.fit(
#   File "/Users/quan/Documents/Concordia Classes/COMP432/speechbrain_moabb_project/speechbrain/speechbrain/core.py", line 1572, in fit
#     self._fit_train(train_set=train_set, epoch=epoch, enable=enable)
#   File "/Users/quan/Documents/Concordia Classes/COMP432/speechbrain_moabb_project/speechbrain/speechbrain/core.py", line 1401, in _fit_train
#     loss = self.fit_batch(batch)
#   File "/Users/quan/Documents/Concordia Classes/COMP432/speechbrain_moabb_project/speechbrain/speechbrain/core.py", line 1195, in fit_batch
#     outputs = self.compute_forward(batch, sb.Stage.TRAIN)
#   File "/Users/quan/Documents/Concordia Classes/COMP432/speechbrain_moabb_project/benchmarks/benchmarks/MOABB/train.py", line 56, in compute_forward
#     return self.modules.model(inputs)
#   File "/Users/quan/.pyenv/versions/3.10.12/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1511, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#   File "/Users/quan/.pyenv/versions/3.10.12/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1520, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/Users/quan/Documents/Concordia Classes/COMP432/speechbrain_moabb_project/benchmarks/benchmarks/MOABB/models/EEGNet.py", line 243, in forward
#     x = self.conv_module(x)
#   File "/Users/quan/.pyenv/versions/3.10.12/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1511, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#   File "/Users/quan/.pyenv/versions/3.10.12/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1520, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/Users/quan/.pyenv/versions/3.10.12/lib/python3.10/site-packages/torch/nn/modules/container.py", line 217, in forward
#     input = module(input)
#   File "/Users/quan/.pyenv/versions/3.10.12/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1511, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#   File "/Users/quan/.pyenv/versions/3.10.12/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1520, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/Users/quan/Documents/Concordia Classes/COMP432/speechbrain_moabb_project/speechbrain/speechbrain/nnet/CNN.py", line 679, in forward
#     wx = self.conv(x)
#   File "/Users/quan/.pyenv/versions/3.10.12/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1511, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#   File "/Users/quan/.pyenv/versions/3.10.12/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1520, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/Users/quan/.pyenv/versions/3.10.12/lib/python3.10/site-packages/torch/nn/modules/conv.py", line 460, in forward
#     return self._conv_forward(input, self.weight, self.bias)
#   File "/Users/quan/.pyenv/versions/3.10.12/lib/python3.10/site-packages/torch/nn/modules/conv.py", line 456, in _conv_forward
#     return F.conv2d(input, weight, bias, self.stride,
# KeyboardInterrupt
